# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer

# Load the model
model_name = "roberta-large"
model = RobertaModel.from_pretrained(model_name)

# Load the tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'yelp_human']
human_test = [data for data in dataset['test'] if data['src'] == 'yelp_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'yelp_human']

llm_train = [data for data in dataset['train'] if 'opt' in data['src'] and 'yelp' in data['src']]
llm_test = [data for data in dataset['test'] if 'opt' in data['src'] and 'yelp' in data['src']]
llm_val = [data for data in dataset['validation'] if 'opt' in data['src'] and 'yelp' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 31827 6955
# 6955 6955
# 868 868
# 867 867

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
def generate_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        last_hidden_states = outputs.last_hidden_state
        embeddings = last_hidden_states[:,0,:].to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,32,32)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,32,32)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 8690 8690 17380 17380
# /tmp/ipykernel_296413/4034461053.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch
import torch.nn as nn
import torch.optim as optim

class CNN(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv2d(8, 2, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # self.conv3 = nn.Conv2d(4, 128, kernel_size=3, stride=1, padding=1)
        # self.relu3 = nn.ReLU()
        # self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(64, 32)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        # x = self.pool3(self.relu3(self.conv3(x)))
        # print(x.shape)
        x = self.flatten(x)
        # print(x.shape)
        x = self.relu4(self.fc1(x))
        x = self.relu5(self.fc2(x))
        x = self.fc3(x) 

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN(in_channels=1, num_classes=2).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.6432
# Validation Accuracy: 0.6680
# TP: 943, FP: 349, TN: 1379, FN: 805
# Epoch [2/100], Loss: 0.5918
# Validation Accuracy: 0.6781
# TP: 837, FP: 208, TN: 1520, FN: 911
# Epoch [3/100], Loss: 0.5581
# Validation Accuracy: 0.7080
# TP: 1561, FP: 828, TN: 900, FN: 187
# Epoch [4/100], Loss: 0.4690
# Validation Accuracy: 0.8001
# TP: 1515, FP: 462, TN: 1266, FN: 233
# Epoch [5/100], Loss: 0.4044
# Validation Accuracy: 0.8107
# TP: 1531, FP: 441, TN: 1287, FN: 217
# Epoch [6/100], Loss: 0.3848
# Validation Accuracy: 0.8242
# TP: 1483, FP: 346, TN: 1382, FN: 265
# Epoch [7/100], Loss: 0.3667
# Validation Accuracy: 0.8277
# TP: 1512, FP: 363, TN: 1365, FN: 236
# Epoch [8/100], Loss: 0.3579
# Validation Accuracy: 0.8297
# TP: 1520, FP: 364, TN: 1364, FN: 228
# Epoch [9/100], Loss: 0.3517
# Validation Accuracy: 0.8116
# TP: 1237, FP: 144, TN: 1584, FN: 511
# Epoch [10/100], Loss: 0.3446
# Validation Accuracy: 0.8386
# TP: 1479, FP: 292, TN: 1436, FN: 269
# Epoch [11/100], Loss: 0.3364
# Validation Accuracy: 0.8363
# TP: 1358, FP: 179, TN: 1549, FN: 390
# Epoch [12/100], Loss: 0.3369
# Validation Accuracy: 0.8449
# TP: 1489, FP: 280, TN: 1448, FN: 259
# Epoch [13/100], Loss: 0.3301
# Validation Accuracy: 0.8369
# TP: 1586, FP: 405, TN: 1323, FN: 162
# Epoch [14/100], Loss: 0.3222
# Validation Accuracy: 0.8501
# TP: 1513, FP: 286, TN: 1442, FN: 235
# Epoch [15/100], Loss: 0.3205
# Validation Accuracy: 0.8481
# TP: 1459, FP: 239, TN: 1489, FN: 289
# Epoch [16/100], Loss: 0.3316
# Validation Accuracy: 0.8283
# TP: 1281, FP: 130, TN: 1598, FN: 467
# Epoch [17/100], Loss: 0.3245
# Validation Accuracy: 0.8481
# TP: 1430, FP: 210, TN: 1518, FN: 318
# Epoch [18/100], Loss: 0.3108
# Validation Accuracy: 0.8513
# TP: 1433, FP: 202, TN: 1526, FN: 315
# Epoch [19/100], Loss: 0.3133
# Validation Accuracy: 0.8403
# TP: 1361, FP: 168, TN: 1560, FN: 387
# Epoch [20/100], Loss: 0.3055
# Validation Accuracy: 0.8501
# TP: 1512, FP: 285, TN: 1443, FN: 236
# Epoch [21/100], Loss: 0.3074
# Validation Accuracy: 0.8579
# TP: 1489, FP: 235, TN: 1493, FN: 259
# Epoch [22/100], Loss: 0.3085
# Validation Accuracy: 0.8472
# TP: 1612, FP: 395, TN: 1333, FN: 136
# Epoch [23/100], Loss: 0.3043
# Validation Accuracy: 0.8585
# TP: 1507, FP: 251, TN: 1477, FN: 241
# Epoch [24/100], Loss: 0.3009
# Validation Accuracy: 0.8587
# TP: 1537, FP: 280, TN: 1448, FN: 211
# Epoch [25/100], Loss: 0.3005
# Validation Accuracy: 0.8530
# TP: 1585, FP: 348, TN: 1380, FN: 163
# Epoch [26/100], Loss: 0.2985
# Validation Accuracy: 0.7906
# TP: 1086, FP: 66, TN: 1662, FN: 662
# Epoch [27/100], Loss: 0.3026
# Validation Accuracy: 0.8593
# TP: 1514, FP: 255, TN: 1473, FN: 234
# Epoch [28/100], Loss: 0.2926
# Validation Accuracy: 0.8464
# TP: 1354, FP: 140, TN: 1588, FN: 394
# Epoch [29/100], Loss: 0.2963
# Validation Accuracy: 0.8562
# TP: 1568, FP: 320, TN: 1408, FN: 180
# Epoch [30/100], Loss: 0.2928
# Validation Accuracy: 0.8576
# TP: 1548, FP: 295, TN: 1433, FN: 200
# Epoch [31/100], Loss: 0.2888
# Validation Accuracy: 0.8596
# TP: 1531, FP: 271, TN: 1457, FN: 217
# Epoch [32/100], Loss: 0.2832
# Validation Accuracy: 0.8527
# TP: 1396, FP: 160, TN: 1568, FN: 352
# Epoch [33/100], Loss: 0.2930
# Validation Accuracy: 0.8579
# TP: 1507, FP: 253, TN: 1475, FN: 241
# Epoch [34/100], Loss: 0.2871
# Validation Accuracy: 0.8570
# TP: 1562, FP: 311, TN: 1417, FN: 186
# Epoch [35/100], Loss: 0.2866
# Validation Accuracy: 0.8455
# TP: 1608, FP: 397, TN: 1331, FN: 140
# Epoch [36/100], Loss: 0.2800
# Validation Accuracy: 0.8507
# TP: 1399, FP: 170, TN: 1558, FN: 349
# Epoch [37/100], Loss: 0.2904
# Validation Accuracy: 0.8530
# TP: 1397, FP: 160, TN: 1568, FN: 351
# Epoch [38/100], Loss: 0.2796
# Validation Accuracy: 0.8642
# TP: 1492, FP: 216, TN: 1512, FN: 256
# Epoch [39/100], Loss: 0.2817
# Validation Accuracy: 0.8645
# TP: 1582, FP: 305, TN: 1423, FN: 166
# Epoch [40/100], Loss: 0.2827
# Validation Accuracy: 0.8596
# TP: 1443, FP: 183, TN: 1545, FN: 305
# Epoch [41/100], Loss: 0.2804
# Validation Accuracy: 0.8444
# TP: 1365, FP: 158, TN: 1570, FN: 383
# Epoch [42/100], Loss: 0.2803
# Validation Accuracy: 0.8501
# TP: 1614, FP: 387, TN: 1341, FN: 134
# Epoch [43/100], Loss: 0.2832
# Validation Accuracy: 0.8590
# TP: 1518, FP: 260, TN: 1468, FN: 230
# Epoch [44/100], Loss: 0.2782
# Validation Accuracy: 0.8631
# TP: 1569, FP: 297, TN: 1431, FN: 179
# Epoch [45/100], Loss: 0.2774
# Validation Accuracy: 0.8429
# TP: 1638, FP: 436, TN: 1292, FN: 110
# Epoch [46/100], Loss: 0.2794
# Validation Accuracy: 0.8366
# TP: 1650, FP: 470, TN: 1258, FN: 98
# Epoch [47/100], Loss: 0.2689
# Validation Accuracy: 0.8651
# TP: 1519, FP: 240, TN: 1488, FN: 229
# Epoch [48/100], Loss: 0.2743
# Validation Accuracy: 0.8587
# TP: 1596, FP: 339, TN: 1389, FN: 152
# Epoch [49/100], Loss: 0.2717
# Validation Accuracy: 0.8628
# TP: 1585, FP: 314, TN: 1414, FN: 163
# Epoch [50/100], Loss: 0.2747
# Validation Accuracy: 0.8452
# TP: 1638, FP: 428, TN: 1300, FN: 110
# Epoch [51/100], Loss: 0.2714
# Validation Accuracy: 0.8631
# TP: 1563, FP: 291, TN: 1437, FN: 185
# Epoch [52/100], Loss: 0.2740
# Validation Accuracy: 0.8645
# TP: 1499, FP: 222, TN: 1506, FN: 249
# Epoch [53/100], Loss: 0.2663
# Validation Accuracy: 0.8587
# TP: 1415, FP: 158, TN: 1570, FN: 333
# Epoch [54/100], Loss: 0.2684
# Validation Accuracy: 0.8645
# TP: 1464, FP: 187, TN: 1541, FN: 284
# Epoch [55/100], Loss: 0.2658
# Validation Accuracy: 0.8651
# TP: 1532, FP: 253, TN: 1475, FN: 216
# Epoch [56/100], Loss: 0.2694
# Validation Accuracy: 0.8438
# TP: 1632, FP: 427, TN: 1301, FN: 116
# Epoch [57/100], Loss: 0.2702
# Validation Accuracy: 0.8636
# TP: 1519, FP: 245, TN: 1483, FN: 229
# Epoch [58/100], Loss: 0.2713
# Validation Accuracy: 0.8659
# TP: 1580, FP: 298, TN: 1430, FN: 168
# Epoch [59/100], Loss: 0.2694
# Validation Accuracy: 0.8659
# TP: 1547, FP: 265, TN: 1463, FN: 201
# Epoch [60/100], Loss: 0.2656
# Validation Accuracy: 0.8642
# TP: 1574, FP: 298, TN: 1430, FN: 174
# Epoch [61/100], Loss: 0.2648
# Validation Accuracy: 0.8633
# TP: 1439, FP: 166, TN: 1562, FN: 309
# Epoch [62/100], Loss: 0.2635
# Validation Accuracy: 0.8674
# TP: 1461, FP: 174, TN: 1554, FN: 287
# Epoch [63/100], Loss: 0.2582
# Validation Accuracy: 0.8573
# TP: 1398, FP: 146, TN: 1582, FN: 350
# Epoch [64/100], Loss: 0.2610
# Validation Accuracy: 0.8639
# TP: 1449, FP: 174, TN: 1554, FN: 299
# Epoch [65/100], Loss: 0.2601
# Validation Accuracy: 0.8648
# TP: 1477, FP: 199, TN: 1529, FN: 271
# Epoch [66/100], Loss: 0.2592
# Validation Accuracy: 0.8533
# TP: 1608, FP: 370, TN: 1358, FN: 140
# Epoch [67/100], Loss: 0.2599
# Validation Accuracy: 0.8674
# TP: 1572, FP: 285, TN: 1443, FN: 176
# Epoch [68/100], Loss: 0.2535
# Validation Accuracy: 0.8639
# TP: 1574, FP: 299, TN: 1429, FN: 174
# Epoch [69/100], Loss: 0.2545
# Validation Accuracy: 0.8636
# TP: 1437, FP: 163, TN: 1565, FN: 311
# Epoch [70/100], Loss: 0.2578
# Validation Accuracy: 0.8674
# TP: 1553, FP: 266, TN: 1462, FN: 195
# Epoch [71/100], Loss: 0.2549
# Validation Accuracy: 0.8694
# TP: 1519, FP: 225, TN: 1503, FN: 229
# Epoch [72/100], Loss: 0.2567
# Validation Accuracy: 0.8412
# TP: 1649, FP: 453, TN: 1275, FN: 99
# Epoch [73/100], Loss: 0.2654
# Validation Accuracy: 0.8671
# TP: 1560, FP: 274, TN: 1454, FN: 188
# Epoch [74/100], Loss: 0.2529
# Validation Accuracy: 0.8639
# TP: 1588, FP: 313, TN: 1415, FN: 160
# Epoch [75/100], Loss: 0.2528
# Validation Accuracy: 0.8602
# TP: 1598, FP: 336, TN: 1392, FN: 150
# Epoch [76/100], Loss: 0.2563
# Validation Accuracy: 0.8682
# TP: 1472, FP: 182, TN: 1546, FN: 276
# Epoch [77/100], Loss: 0.2562
# Validation Accuracy: 0.8645
# TP: 1489, FP: 212, TN: 1516, FN: 259
# Epoch [78/100], Loss: 0.2516
# Validation Accuracy: 0.8711
# TP: 1558, FP: 258, TN: 1470, FN: 190
# Epoch [79/100], Loss: 0.2497
# Validation Accuracy: 0.8642
# TP: 1524, FP: 248, TN: 1480, FN: 224
# Epoch [80/100], Loss: 0.2467
# Validation Accuracy: 0.8711
# TP: 1531, FP: 231, TN: 1497, FN: 217
# Epoch [81/100], Loss: 0.2459
# Validation Accuracy: 0.8700
# TP: 1503, FP: 207, TN: 1521, FN: 245
# Epoch [82/100], Loss: 0.2481
# Validation Accuracy: 0.8711
# TP: 1505, FP: 205, TN: 1523, FN: 243
# Epoch [83/100], Loss: 0.2452
# Validation Accuracy: 0.8573
# TP: 1628, FP: 376, TN: 1352, FN: 120
# Epoch [84/100], Loss: 0.2468
# Validation Accuracy: 0.8674
# TP: 1563, FP: 276, TN: 1452, FN: 185
# Epoch [85/100], Loss: 0.2457
# Validation Accuracy: 0.8389
# TP: 1651, FP: 463, TN: 1265, FN: 97
# Epoch [86/100], Loss: 0.2465
# Validation Accuracy: 0.8685
# TP: 1550, FP: 259, TN: 1469, FN: 198
# Epoch [87/100], Loss: 0.2473
# Validation Accuracy: 0.8619
# TP: 1409, FP: 141, TN: 1587, FN: 339
# Epoch [88/100], Loss: 0.2483
# Validation Accuracy: 0.8720
# TP: 1589, FP: 286, TN: 1442, FN: 159
# Epoch [89/100], Loss: 0.2418
# Validation Accuracy: 0.8697
# TP: 1455, FP: 160, TN: 1568, FN: 293
# Epoch [90/100], Loss: 0.2417
# Validation Accuracy: 0.8662
# TP: 1573, FP: 290, TN: 1438, FN: 175
# Epoch [91/100], Loss: 0.2458
# Validation Accuracy: 0.8631
# TP: 1606, FP: 334, TN: 1394, FN: 142
# Epoch [92/100], Loss: 0.2348
# Validation Accuracy: 0.8694
# TP: 1575, FP: 281, TN: 1447, FN: 173
# Epoch [93/100], Loss: 0.2494
# Validation Accuracy: 0.8703
# TP: 1542, FP: 245, TN: 1483, FN: 206
# Epoch [94/100], Loss: 0.2421
# Validation Accuracy: 0.8648
# TP: 1613, FP: 335, TN: 1393, FN: 135
# Epoch [95/100], Loss: 0.2380
# Validation Accuracy: 0.8682
# TP: 1537, FP: 247, TN: 1481, FN: 211
# Epoch [96/100], Loss: 0.2424
# Validation Accuracy: 0.8651
# TP: 1594, FP: 315, TN: 1413, FN: 154
# Epoch [97/100], Loss: 0.2422
# Validation Accuracy: 0.8708
# TP: 1527, FP: 228, TN: 1500, FN: 221
# Epoch [98/100], Loss: 0.2358
# Validation Accuracy: 0.8714
# TP: 1498, FP: 197, TN: 1531, FN: 250
# Epoch [99/100], Loss: 0.2405
# Validation Accuracy: 0.8688
# TP: 1566, FP: 274, TN: 1454, FN: 182
# Epoch [100/100], Loss: 0.2370
# Validation Accuracy: 0.8616
# TP: 1434, FP: 167, TN: 1561, FN: 314

# %%
print("Maximum Validation Accuracy: ", max_val_accuracy)
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.4f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.4f}')
print(f'False Positive Rate (FPR): {FPR:.4f}')
# Out:
# Maximum Validation Accuracy:  0.8719792865362486
# TP:  1589
# FP:  286
# TN:  1442
# FN:  159
# Matthews Correlation Coefficient (MCC): 0.7458
# True Positive Rate (TPR): 0.9090
# False Positive Rate (FPR): 0.1655

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Yelp/BERT/opt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
