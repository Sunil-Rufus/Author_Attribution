# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer

# Load the model
model_name = "roberta-large"
model = RobertaModel.from_pretrained(model_name)

# Load the tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'yelp_human']
human_test = [data for data in dataset['test'] if data['src'] == 'yelp_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'yelp_human']

llm_train = [data for data in dataset['train'] if 'gpt' in data['src'] and 'yelp' in data['src']]
llm_test = [data for data in dataset['test'] if 'gpt' in data['src'] and 'yelp' in data['src']]
llm_val = [data for data in dataset['validation'] if 'gpt' in data['src'] and 'yelp' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 31827 2223
# 2223 2223
# 274 274
# 272 272

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
def generate_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        last_hidden_states = outputs.last_hidden_state
        embeddings = last_hidden_states[:,0,:].to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,32,32)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,32,32)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 2769 2769 5538 5538
# /tmp/ipykernel_299969/4034461053.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch
import torch.nn as nn
import torch.optim as optim

class CNN(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv2d(8, 2, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # self.conv3 = nn.Conv2d(4, 128, kernel_size=3, stride=1, padding=1)
        # self.relu3 = nn.ReLU()
        # self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(64, 32)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        # x = self.pool3(self.relu3(self.conv3(x)))
        # print(x.shape)
        x = self.flatten(x)
        # print(x.shape)
        x = self.relu4(self.fc1(x))
        x = self.relu5(self.fc2(x))
        x = self.fc3(x) 

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN(in_channels=1, num_classes=2).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.6877
# Validation Accuracy: 0.6408
# TP: 362, FP: 223, TN: 348, FN: 175
# Epoch [2/100], Loss: 0.6609
# Validation Accuracy: 0.6570
# TP: 283, FP: 126, TN: 445, FN: 254
# Epoch [3/100], Loss: 0.6314
# Validation Accuracy: 0.7013
# TP: 329, FP: 123, TN: 448, FN: 208
# Epoch [4/100], Loss: 0.6013
# Validation Accuracy: 0.7130
# TP: 449, FP: 230, TN: 341, FN: 88
# Epoch [5/100], Loss: 0.5486
# Validation Accuracy: 0.7581
# TP: 474, FP: 205, TN: 366, FN: 63
# Epoch [6/100], Loss: 0.4907
# Validation Accuracy: 0.7329
# TP: 506, FP: 265, TN: 306, FN: 31
# Epoch [7/100], Loss: 0.4301
# Validation Accuracy: 0.8321
# TP: 437, FP: 86, TN: 485, FN: 100
# Epoch [8/100], Loss: 0.3986
# Validation Accuracy: 0.8375
# TP: 400, FP: 43, TN: 528, FN: 137
# Epoch [9/100], Loss: 0.3755
# Validation Accuracy: 0.8466
# TP: 433, FP: 66, TN: 505, FN: 104
# Epoch [10/100], Loss: 0.3545
# Validation Accuracy: 0.7879
# TP: 510, FP: 208, TN: 363, FN: 27
# Epoch [11/100], Loss: 0.3570
# Validation Accuracy: 0.8366
# TP: 390, FP: 34, TN: 537, FN: 147
# Epoch [12/100], Loss: 0.3442
# Validation Accuracy: 0.8610
# TP: 456, FP: 73, TN: 498, FN: 81
# Epoch [13/100], Loss: 0.3191
# Validation Accuracy: 0.8682
# TP: 459, FP: 68, TN: 503, FN: 78
# Epoch [14/100], Loss: 0.3161
# Validation Accuracy: 0.8592
# TP: 422, FP: 41, TN: 530, FN: 115
# Epoch [15/100], Loss: 0.3125
# Validation Accuracy: 0.8664
# TP: 485, FP: 96, TN: 475, FN: 52
# Epoch [16/100], Loss: 0.3033
# Validation Accuracy: 0.8601
# TP: 420, FP: 38, TN: 533, FN: 117
# Epoch [17/100], Loss: 0.3042
# Validation Accuracy: 0.8637
# TP: 425, FP: 39, TN: 532, FN: 112
# Epoch [18/100], Loss: 0.3047
# Validation Accuracy: 0.8691
# TP: 478, FP: 86, TN: 485, FN: 59
# Epoch [19/100], Loss: 0.2874
# Validation Accuracy: 0.8709
# TP: 454, FP: 60, TN: 511, FN: 83
# Epoch [20/100], Loss: 0.2760
# Validation Accuracy: 0.8592
# TP: 500, FP: 119, TN: 452, FN: 37
# Epoch [21/100], Loss: 0.2796
# Validation Accuracy: 0.8366
# TP: 507, FP: 151, TN: 420, FN: 30
# Epoch [22/100], Loss: 0.2858
# Validation Accuracy: 0.8736
# TP: 495, FP: 98, TN: 473, FN: 42
# Epoch [23/100], Loss: 0.2728
# Validation Accuracy: 0.8718
# TP: 465, FP: 70, TN: 501, FN: 72
# Epoch [24/100], Loss: 0.2789
# Validation Accuracy: 0.8718
# TP: 484, FP: 89, TN: 482, FN: 53
# Epoch [25/100], Loss: 0.2744
# Validation Accuracy: 0.8709
# TP: 501, FP: 107, TN: 464, FN: 36
# Epoch [26/100], Loss: 0.2657
# Validation Accuracy: 0.8664
# TP: 493, FP: 104, TN: 467, FN: 44
# Epoch [27/100], Loss: 0.2559
# Validation Accuracy: 0.8619
# TP: 497, FP: 113, TN: 458, FN: 40
# Epoch [28/100], Loss: 0.2551
# Validation Accuracy: 0.8818
# TP: 478, FP: 72, TN: 499, FN: 59
# Epoch [29/100], Loss: 0.2529
# Validation Accuracy: 0.8574
# TP: 410, FP: 31, TN: 540, FN: 127
# Epoch [30/100], Loss: 0.2589
# Validation Accuracy: 0.8484
# TP: 397, FP: 28, TN: 543, FN: 140
# Epoch [31/100], Loss: 0.2580
# Validation Accuracy: 0.8727
# TP: 435, FP: 39, TN: 532, FN: 102
# Epoch [32/100], Loss: 0.2688
# Validation Accuracy: 0.8764
# TP: 486, FP: 86, TN: 485, FN: 51
# Epoch [33/100], Loss: 0.2440
# Validation Accuracy: 0.8755
# TP: 441, FP: 42, TN: 529, FN: 96
# Epoch [34/100], Loss: 0.2552
# Validation Accuracy: 0.8727
# TP: 483, FP: 87, TN: 484, FN: 54
# Epoch [35/100], Loss: 0.2474
# Validation Accuracy: 0.8366
# TP: 515, FP: 159, TN: 412, FN: 22
# Epoch [36/100], Loss: 0.2482
# Validation Accuracy: 0.8655
# TP: 498, FP: 110, TN: 461, FN: 39
# Epoch [37/100], Loss: 0.2484
# Validation Accuracy: 0.8755
# TP: 474, FP: 75, TN: 496, FN: 63
# Epoch [38/100], Loss: 0.2364
# Validation Accuracy: 0.8764
# TP: 478, FP: 78, TN: 493, FN: 59
# Epoch [39/100], Loss: 0.2441
# Validation Accuracy: 0.8800
# TP: 486, FP: 82, TN: 489, FN: 51
# Epoch [40/100], Loss: 0.2416
# Validation Accuracy: 0.8854
# TP: 470, FP: 60, TN: 511, FN: 67
# Epoch [41/100], Loss: 0.2320
# Validation Accuracy: 0.8845
# TP: 455, FP: 46, TN: 525, FN: 82
# Epoch [42/100], Loss: 0.2301
# Validation Accuracy: 0.8881
# TP: 469, FP: 56, TN: 515, FN: 68
# Epoch [43/100], Loss: 0.2243
# Validation Accuracy: 0.8755
# TP: 483, FP: 84, TN: 487, FN: 54
# Epoch [44/100], Loss: 0.2329
# Validation Accuracy: 0.8809
# TP: 478, FP: 73, TN: 498, FN: 59
# Epoch [45/100], Loss: 0.2387
# Validation Accuracy: 0.8908
# TP: 480, FP: 64, TN: 507, FN: 57
# Epoch [46/100], Loss: 0.2318
# Validation Accuracy: 0.8791
# TP: 495, FP: 92, TN: 479, FN: 42
# Epoch [47/100], Loss: 0.2438
# Validation Accuracy: 0.8890
# TP: 476, FP: 62, TN: 509, FN: 61
# Epoch [48/100], Loss: 0.2188
# Validation Accuracy: 0.8863
# TP: 481, FP: 70, TN: 501, FN: 56
# Epoch [49/100], Loss: 0.2438
# Validation Accuracy: 0.8836
# TP: 453, FP: 45, TN: 526, FN: 84
# Epoch [50/100], Loss: 0.2205
# Validation Accuracy: 0.8809
# TP: 488, FP: 83, TN: 488, FN: 49
# Epoch [51/100], Loss: 0.2169
# Validation Accuracy: 0.8836
# TP: 448, FP: 40, TN: 531, FN: 89
# Epoch [52/100], Loss: 0.2377
# Validation Accuracy: 0.8881
# TP: 474, FP: 61, TN: 510, FN: 63
# Epoch [53/100], Loss: 0.2293
# Validation Accuracy: 0.8863
# TP: 461, FP: 50, TN: 521, FN: 76
# Epoch [54/100], Loss: 0.2318
# Validation Accuracy: 0.8800
# TP: 447, FP: 43, TN: 528, FN: 90
# Epoch [55/100], Loss: 0.2235
# Validation Accuracy: 0.8845
# TP: 487, FP: 78, TN: 493, FN: 50
# Epoch [56/100], Loss: 0.2104
# Validation Accuracy: 0.8827
# TP: 496, FP: 89, TN: 482, FN: 41
# Epoch [57/100], Loss: 0.2100
# Validation Accuracy: 0.8863
# TP: 482, FP: 71, TN: 500, FN: 55
# Epoch [58/100], Loss: 0.2054
# Validation Accuracy: 0.8953
# TP: 473, FP: 52, TN: 519, FN: 64
# Epoch [59/100], Loss: 0.2105
# Validation Accuracy: 0.8854
# TP: 482, FP: 72, TN: 499, FN: 55
# Epoch [60/100], Loss: 0.2121
# Validation Accuracy: 0.8890
# TP: 479, FP: 65, TN: 506, FN: 58
# Epoch [61/100], Loss: 0.2113
# Validation Accuracy: 0.8809
# TP: 448, FP: 43, TN: 528, FN: 89
# Epoch [62/100], Loss: 0.2090
# Validation Accuracy: 0.8917
# TP: 467, FP: 50, TN: 521, FN: 70
# Epoch [63/100], Loss: 0.2072
# Validation Accuracy: 0.8782
# TP: 496, FP: 94, TN: 477, FN: 41
# Epoch [64/100], Loss: 0.2002
# Validation Accuracy: 0.8818
# TP: 495, FP: 89, TN: 482, FN: 42
# Epoch [65/100], Loss: 0.2069
# Validation Accuracy: 0.8845
# TP: 475, FP: 66, TN: 505, FN: 62
# Epoch [66/100], Loss: 0.2071
# Validation Accuracy: 0.8782
# TP: 437, FP: 35, TN: 536, FN: 100
# Epoch [67/100], Loss: 0.2004
# Validation Accuracy: 0.8890
# TP: 484, FP: 70, TN: 501, FN: 53
# Epoch [68/100], Loss: 0.2158
# Validation Accuracy: 0.8745
# TP: 431, FP: 33, TN: 538, FN: 106
# Epoch [69/100], Loss: 0.2038
# Validation Accuracy: 0.8863
# TP: 475, FP: 64, TN: 507, FN: 62
# Epoch [70/100], Loss: 0.2074
# Validation Accuracy: 0.8899
# TP: 478, FP: 63, TN: 508, FN: 59
# Epoch [71/100], Loss: 0.2203
# Validation Accuracy: 0.8736
# TP: 503, FP: 106, TN: 465, FN: 34
# Epoch [72/100], Loss: 0.2054
# Validation Accuracy: 0.8836
# TP: 485, FP: 77, TN: 494, FN: 52
# Epoch [73/100], Loss: 0.1933
# Validation Accuracy: 0.8845
# TP: 494, FP: 85, TN: 486, FN: 43
# Epoch [74/100], Loss: 0.1875
# Validation Accuracy: 0.8908
# TP: 477, FP: 61, TN: 510, FN: 60
# Epoch [75/100], Loss: 0.1890
# Validation Accuracy: 0.8881
# TP: 487, FP: 74, TN: 497, FN: 50
# Epoch [76/100], Loss: 0.2075
# Validation Accuracy: 0.8908
# TP: 471, FP: 55, TN: 516, FN: 66
# Epoch [77/100], Loss: 0.1968
# Validation Accuracy: 0.8881
# TP: 478, FP: 65, TN: 506, FN: 59
# Epoch [78/100], Loss: 0.2026
# Validation Accuracy: 0.8755
# TP: 431, FP: 32, TN: 539, FN: 106
# Epoch [79/100], Loss: 0.2110
# Validation Accuracy: 0.8872
# TP: 479, FP: 67, TN: 504, FN: 58
# Epoch [80/100], Loss: 0.1896
# Validation Accuracy: 0.8845
# TP: 487, FP: 78, TN: 493, FN: 50
# Epoch [81/100], Loss: 0.1903
# Validation Accuracy: 0.8745
# TP: 494, FP: 96, TN: 475, FN: 43
# Epoch [82/100], Loss: 0.1911
# Validation Accuracy: 0.8980
# TP: 485, FP: 61, TN: 510, FN: 52
# Epoch [83/100], Loss: 0.1880
# Validation Accuracy: 0.8872
# TP: 491, FP: 79, TN: 492, FN: 46
# Epoch [84/100], Loss: 0.1842
# Validation Accuracy: 0.8926
# TP: 479, FP: 61, TN: 510, FN: 58
# Epoch [85/100], Loss: 0.1884
# Validation Accuracy: 0.8872
# TP: 488, FP: 76, TN: 495, FN: 49
# Epoch [86/100], Loss: 0.1866
# Validation Accuracy: 0.8917
# TP: 464, FP: 47, TN: 524, FN: 73
# Epoch [87/100], Loss: 0.1791
# Validation Accuracy: 0.8980
# TP: 477, FP: 53, TN: 518, FN: 60
# Epoch [88/100], Loss: 0.1921
# Validation Accuracy: 0.8448
# TP: 516, FP: 151, TN: 420, FN: 21
# Epoch [89/100], Loss: 0.1938
# Validation Accuracy: 0.8628
# TP: 512, FP: 127, TN: 444, FN: 25
# Epoch [90/100], Loss: 0.1989
# Validation Accuracy: 0.8917
# TP: 478, FP: 61, TN: 510, FN: 59
# Epoch [91/100], Loss: 0.1847
# Validation Accuracy: 0.8845
# TP: 496, FP: 87, TN: 484, FN: 41
# Epoch [92/100], Loss: 0.1882
# Validation Accuracy: 0.8818
# TP: 436, FP: 30, TN: 541, FN: 101
# Epoch [93/100], Loss: 0.1848
# Validation Accuracy: 0.8899
# TP: 448, FP: 33, TN: 538, FN: 89
# Epoch [94/100], Loss: 0.1865
# Validation Accuracy: 0.8854
# TP: 484, FP: 74, TN: 497, FN: 53
# Epoch [95/100], Loss: 0.1897
# Validation Accuracy: 0.8944
# TP: 470, FP: 50, TN: 521, FN: 67
# Epoch [96/100], Loss: 0.1800
# Validation Accuracy: 0.8872
# TP: 485, FP: 73, TN: 498, FN: 52
# Epoch [97/100], Loss: 0.1754
# Validation Accuracy: 0.8800
# TP: 495, FP: 91, TN: 480, FN: 42
# Epoch [98/100], Loss: 0.1767
# Validation Accuracy: 0.8782
# TP: 503, FP: 101, TN: 470, FN: 34
# Epoch [99/100], Loss: 0.1778
# Validation Accuracy: 0.8899
# TP: 467, FP: 52, TN: 519, FN: 70
# Epoch [100/100], Loss: 0.1773
# Validation Accuracy: 0.8953
# TP: 461, FP: 40, TN: 531, FN: 76

# %%
print("Maximum Validation Accuracy: ", max_val_accuracy)
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.4f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.4f}')
print(f'False Positive Rate (FPR): {FPR:.4f}')
# Out:
# Maximum Validation Accuracy:  0.898014440433213
# TP:  485
# FP:  61
# TN:  510
# FN:  52
# Matthews Correlation Coefficient (MCC): 0.7960
# True Positive Rate (TPR): 0.9032
# False Positive Rate (FPR): 0.1068

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Yelp/BERT/gpt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
