# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer

# Load the model
model_name = "roberta-large"
model = RobertaModel.from_pretrained(model_name)

# Load the tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'yelp_human']
human_test = [data for data in dataset['test'] if data['src'] == 'yelp_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'yelp_human']

llm_train = [data for data in dataset['train'] if 'flan' in data['src'] and 'yelp' in data['src']]
llm_test = [data for data in dataset['test'] if 'flan' in data['src'] and 'yelp' in data['src']]
llm_val = [data for data in dataset['validation'] if 'flan' in data['src'] and 'yelp' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 31827 3943
# 3943 3943
# 490 490
# 492 492

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
def generate_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        last_hidden_states = outputs.last_hidden_state
        embeddings = last_hidden_states[:,0,:].to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,32,32)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,32,32)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 4925 4925 9850 9850
# /tmp/ipykernel_296378/4034461053.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class CNN(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv2d(8, 2, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # self.conv3 = nn.Conv2d(4, 128, kernel_size=3, stride=1, padding=1)
        # self.relu3 = nn.ReLU()
        # self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(64, 32)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        # x = self.pool3(self.relu3(self.conv3(x)))
        # print(x.shape)
        x = self.flatten(x)
        # print(x.shape)
        x = self.relu4(self.fc1(x))
        x = self.relu5(self.fc2(x))
        x = self.fc3(x) 

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN(in_channels=1, num_classes=2).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total 
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.6325
# Validation Accuracy: 0.7142
# TP: 587, FP: 166, TN: 820, FN: 397
# Epoch [2/100], Loss: 0.5647
# Validation Accuracy: 0.7269
# TP: 637, FP: 191, TN: 795, FN: 347
# Epoch [3/100], Loss: 0.5205
# Validation Accuracy: 0.7640
# TP: 611, FP: 92, TN: 894, FN: 373
# Epoch [4/100], Loss: 0.4873
# Validation Accuracy: 0.7812
# TP: 651, FP: 98, TN: 888, FN: 333
# Epoch [5/100], Loss: 0.4736
# Validation Accuracy: 0.7904
# TP: 654, FP: 83, TN: 903, FN: 330
# Epoch [6/100], Loss: 0.4625
# Validation Accuracy: 0.7721
# TP: 724, FP: 189, TN: 797, FN: 260
# Epoch [7/100], Loss: 0.4466
# Validation Accuracy: 0.7939
# TP: 636, FP: 58, TN: 928, FN: 348
# Epoch [8/100], Loss: 0.4369
# Validation Accuracy: 0.7939
# TP: 622, FP: 44, TN: 942, FN: 362
# Epoch [9/100], Loss: 0.4305
# Validation Accuracy: 0.7807
# TP: 726, FP: 174, TN: 812, FN: 258
# Epoch [10/100], Loss: 0.4238
# Validation Accuracy: 0.7777
# TP: 571, FP: 25, TN: 961, FN: 413
# Epoch [11/100], Loss: 0.4258
# Validation Accuracy: 0.7888
# TP: 747, FP: 179, TN: 807, FN: 237
# Epoch [12/100], Loss: 0.4136
# Validation Accuracy: 0.7797
# TP: 584, FP: 34, TN: 952, FN: 400
# Epoch [13/100], Loss: 0.3988
# Validation Accuracy: 0.8066
# TP: 758, FP: 155, TN: 831, FN: 226
# Epoch [14/100], Loss: 0.3917
# Validation Accuracy: 0.8066
# TP: 737, FP: 134, TN: 852, FN: 247
# Epoch [15/100], Loss: 0.3854
# Validation Accuracy: 0.8117
# TP: 711, FP: 98, TN: 888, FN: 273
# Epoch [16/100], Loss: 0.3838
# Validation Accuracy: 0.8086
# TP: 697, FP: 90, TN: 896, FN: 287
# Epoch [17/100], Loss: 0.3722
# Validation Accuracy: 0.8107
# TP: 684, FP: 73, TN: 913, FN: 300
# Epoch [18/100], Loss: 0.3636
# Validation Accuracy: 0.8137
# TP: 720, FP: 103, TN: 883, FN: 264
# Epoch [19/100], Loss: 0.3565
# Validation Accuracy: 0.7995
# TP: 620, FP: 31, TN: 955, FN: 364
# Epoch [20/100], Loss: 0.3476
# Validation Accuracy: 0.8218
# TP: 801, FP: 168, TN: 818, FN: 183
# Epoch [21/100], Loss: 0.3468
# Validation Accuracy: 0.8259
# TP: 775, FP: 134, TN: 852, FN: 209
# Epoch [22/100], Loss: 0.3409
# Validation Accuracy: 0.8025
# TP: 621, FP: 26, TN: 960, FN: 363
# Epoch [23/100], Loss: 0.3407
# Validation Accuracy: 0.8157
# TP: 685, FP: 64, TN: 922, FN: 299
# Epoch [24/100], Loss: 0.3347
# Validation Accuracy: 0.8264
# TP: 726, FP: 84, TN: 902, FN: 258
# Epoch [25/100], Loss: 0.3265
# Validation Accuracy: 0.8051
# TP: 631, FP: 31, TN: 955, FN: 353
# Epoch [26/100], Loss: 0.3338
# Validation Accuracy: 0.8091
# TP: 890, FP: 282, TN: 704, FN: 94
# Epoch [27/100], Loss: 0.3292
# Validation Accuracy: 0.8274
# TP: 834, FP: 190, TN: 796, FN: 150
# Epoch [28/100], Loss: 0.3278
# Validation Accuracy: 0.8437
# TP: 796, FP: 120, TN: 866, FN: 188
# Epoch [29/100], Loss: 0.3254
# Validation Accuracy: 0.8411
# TP: 810, FP: 139, TN: 847, FN: 174
# Epoch [30/100], Loss: 0.3220
# Validation Accuracy: 0.8437
# TP: 777, FP: 101, TN: 885, FN: 207
# Epoch [31/100], Loss: 0.3136
# Validation Accuracy: 0.8239
# TP: 849, FP: 212, TN: 774, FN: 135
# Epoch [32/100], Loss: 0.3195
# Validation Accuracy: 0.8173
# TP: 861, FP: 237, TN: 749, FN: 123
# Epoch [33/100], Loss: 0.3101
# Validation Accuracy: 0.8330
# TP: 741, FP: 86, TN: 900, FN: 243
# Epoch [34/100], Loss: 0.3125
# Validation Accuracy: 0.8381
# TP: 750, FP: 85, TN: 901, FN: 234
# Epoch [35/100], Loss: 0.3106
# Validation Accuracy: 0.8091
# TP: 657, FP: 49, TN: 937, FN: 327
# Epoch [36/100], Loss: 0.3142
# Validation Accuracy: 0.8345
# TP: 725, FP: 67, TN: 919, FN: 259
# Epoch [37/100], Loss: 0.3269
# Validation Accuracy: 0.8345
# TP: 720, FP: 62, TN: 924, FN: 264
# Epoch [38/100], Loss: 0.3118
# Validation Accuracy: 0.8431
# TP: 779, FP: 104, TN: 882, FN: 205
# Epoch [39/100], Loss: 0.2996
# Validation Accuracy: 0.8264
# TP: 823, FP: 181, TN: 805, FN: 161
# Epoch [40/100], Loss: 0.3032
# Validation Accuracy: 0.8325
# TP: 706, FP: 52, TN: 934, FN: 278
# Epoch [41/100], Loss: 0.3034
# Validation Accuracy: 0.8386
# TP: 748, FP: 82, TN: 904, FN: 236
# Epoch [42/100], Loss: 0.2979
# Validation Accuracy: 0.8431
# TP: 829, FP: 154, TN: 832, FN: 155
# Epoch [43/100], Loss: 0.2933
# Validation Accuracy: 0.8376
# TP: 836, FP: 172, TN: 814, FN: 148
# Epoch [44/100], Loss: 0.3036
# Validation Accuracy: 0.8467
# TP: 781, FP: 99, TN: 887, FN: 203
# Epoch [45/100], Loss: 0.3040
# Validation Accuracy: 0.8274
# TP: 870, FP: 226, TN: 760, FN: 114
# Epoch [46/100], Loss: 0.2968
# Validation Accuracy: 0.8406
# TP: 768, FP: 98, TN: 888, FN: 216
# Epoch [47/100], Loss: 0.2911
# Validation Accuracy: 0.8162
# TP: 876, FP: 254, TN: 732, FN: 108
# Epoch [48/100], Loss: 0.2882
# Validation Accuracy: 0.8503
# TP: 818, FP: 129, TN: 857, FN: 166
# Epoch [49/100], Loss: 0.2930
# Validation Accuracy: 0.8203
# TP: 868, FP: 238, TN: 748, FN: 116
# Epoch [50/100], Loss: 0.2855
# Validation Accuracy: 0.8142
# TP: 879, FP: 261, TN: 725, FN: 105
# Epoch [51/100], Loss: 0.2929
# Validation Accuracy: 0.8416
# TP: 763, FP: 91, TN: 895, FN: 221
# Epoch [52/100], Loss: 0.2897
# Validation Accuracy: 0.8188
# TP: 696, FP: 69, TN: 917, FN: 288
# Epoch [53/100], Loss: 0.2872
# Validation Accuracy: 0.8421
# TP: 821, FP: 148, TN: 838, FN: 163
# Epoch [54/100], Loss: 0.2864
# Validation Accuracy: 0.8371
# TP: 736, FP: 73, TN: 913, FN: 248
# Epoch [55/100], Loss: 0.2897
# Validation Accuracy: 0.8467
# TP: 781, FP: 99, TN: 887, FN: 203
# Epoch [56/100], Loss: 0.2834
# Validation Accuracy: 0.8365
# TP: 831, FP: 169, TN: 817, FN: 153
# Epoch [57/100], Loss: 0.2849
# Validation Accuracy: 0.8477
# TP: 815, FP: 131, TN: 855, FN: 169
# Epoch [58/100], Loss: 0.2788
# Validation Accuracy: 0.8132
# TP: 648, FP: 32, TN: 954, FN: 336
# Epoch [59/100], Loss: 0.2824
# Validation Accuracy: 0.8355
# TP: 738, FP: 78, TN: 908, FN: 246
# Epoch [60/100], Loss: 0.2815
# Validation Accuracy: 0.8391
# TP: 767, FP: 100, TN: 886, FN: 217
# Epoch [61/100], Loss: 0.2758
# Validation Accuracy: 0.8360
# TP: 736, FP: 75, TN: 911, FN: 248
# Epoch [62/100], Loss: 0.2837
# Validation Accuracy: 0.8447
# TP: 775, FP: 97, TN: 889, FN: 209
# Epoch [63/100], Loss: 0.2771
# Validation Accuracy: 0.8487
# TP: 798, FP: 112, TN: 874, FN: 186
# Epoch [64/100], Loss: 0.2766
# Validation Accuracy: 0.8299
# TP: 717, FP: 68, TN: 918, FN: 267
# Epoch [65/100], Loss: 0.2769
# Validation Accuracy: 0.8406
# TP: 776, FP: 106, TN: 880, FN: 208
# Epoch [66/100], Loss: 0.2765
# Validation Accuracy: 0.8467
# TP: 758, FP: 76, TN: 910, FN: 226
# Epoch [67/100], Loss: 0.2701
# Validation Accuracy: 0.8482
# TP: 812, FP: 127, TN: 859, FN: 172
# Epoch [68/100], Loss: 0.2695
# Validation Accuracy: 0.8482
# TP: 819, FP: 134, TN: 852, FN: 165
# Epoch [69/100], Loss: 0.2646
# Validation Accuracy: 0.8437
# TP: 816, FP: 140, TN: 846, FN: 168
# Epoch [70/100], Loss: 0.2755
# Validation Accuracy: 0.8462
# TP: 806, FP: 125, TN: 861, FN: 178
# Epoch [71/100], Loss: 0.2686
# Validation Accuracy: 0.8457
# TP: 809, FP: 129, TN: 857, FN: 175
# Epoch [72/100], Loss: 0.2678
# Validation Accuracy: 0.8437
# TP: 839, FP: 163, TN: 823, FN: 145
# Epoch [73/100], Loss: 0.2671
# Validation Accuracy: 0.8533
# TP: 797, FP: 102, TN: 884, FN: 187
# Epoch [74/100], Loss: 0.2657
# Validation Accuracy: 0.8513
# TP: 833, FP: 142, TN: 844, FN: 151
# Epoch [75/100], Loss: 0.2609
# Validation Accuracy: 0.8472
# TP: 789, FP: 106, TN: 880, FN: 195
# Epoch [76/100], Loss: 0.2676
# Validation Accuracy: 0.8538
# TP: 808, FP: 112, TN: 874, FN: 176
# Epoch [77/100], Loss: 0.2621
# Validation Accuracy: 0.8421
# TP: 760, FP: 87, TN: 899, FN: 224
# Epoch [78/100], Loss: 0.2627
# Validation Accuracy: 0.8350
# TP: 818, FP: 159, TN: 827, FN: 166
# Epoch [79/100], Loss: 0.2672
# Validation Accuracy: 0.8462
# TP: 829, FP: 148, TN: 838, FN: 155
# Epoch [80/100], Loss: 0.2688
# Validation Accuracy: 0.8437
# TP: 778, FP: 102, TN: 884, FN: 206
# Epoch [81/100], Loss: 0.2653
# Validation Accuracy: 0.8528
# TP: 813, FP: 119, TN: 867, FN: 171
# Epoch [82/100], Loss: 0.2656
# Validation Accuracy: 0.8452
# TP: 838, FP: 159, TN: 827, FN: 146
# Epoch [83/100], Loss: 0.2611
# Validation Accuracy: 0.8386
# TP: 855, FP: 189, TN: 797, FN: 129
# Epoch [84/100], Loss: 0.2590
# Validation Accuracy: 0.8447
# TP: 756, FP: 78, TN: 908, FN: 228
# Epoch [85/100], Loss: 0.2535
# Validation Accuracy: 0.8401
# TP: 821, FP: 152, TN: 834, FN: 163
# Epoch [86/100], Loss: 0.2576
# Validation Accuracy: 0.8234
# TP: 675, FP: 39, TN: 947, FN: 309
# Epoch [87/100], Loss: 0.2774
# Validation Accuracy: 0.8487
# TP: 780, FP: 94, TN: 892, FN: 204
# Epoch [88/100], Loss: 0.2523
# Validation Accuracy: 0.8411
# TP: 844, FP: 173, TN: 813, FN: 140
# Epoch [89/100], Loss: 0.2541
# Validation Accuracy: 0.8574
# TP: 810, FP: 107, TN: 879, FN: 174
# Epoch [90/100], Loss: 0.2565
# Validation Accuracy: 0.8462
# TP: 777, FP: 96, TN: 890, FN: 207
# Epoch [91/100], Loss: 0.2645
# Validation Accuracy: 0.8244
# TP: 863, FP: 225, TN: 761, FN: 121
# Epoch [92/100], Loss: 0.2485
# Validation Accuracy: 0.8569
# TP: 820, FP: 118, TN: 868, FN: 164
# Epoch [93/100], Loss: 0.2551
# Validation Accuracy: 0.8457
# TP: 830, FP: 150, TN: 836, FN: 154
# Epoch [94/100], Loss: 0.2479
# Validation Accuracy: 0.8457
# TP: 777, FP: 97, TN: 889, FN: 207
# Epoch [95/100], Loss: 0.2539
# Validation Accuracy: 0.8508
# TP: 817, FP: 127, TN: 859, FN: 167
# Epoch [96/100], Loss: 0.2517
# Validation Accuracy: 0.8447
# TP: 754, FP: 76, TN: 910, FN: 230
# Epoch [97/100], Loss: 0.2546
# Validation Accuracy: 0.8345
# TP: 825, FP: 167, TN: 819, FN: 159
# Epoch [98/100], Loss: 0.2573
# Validation Accuracy: 0.8503
# TP: 774, FP: 85, TN: 901, FN: 210
# Epoch [99/100], Loss: 0.2499
# Validation Accuracy: 0.8503
# TP: 757, FP: 68, TN: 918, FN: 227
# Epoch [100/100], Loss: 0.2435
# Validation Accuracy: 0.8513
# TP: 821, FP: 130, TN: 856, FN: 163

# %%
print("Maximum Validation Accuracy: ", max_val_accuracy)
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.4f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.4f}')
print(f'False Positive Rate (FPR): {FPR:.4f}')
# Out:
# Maximum Validation Accuracy:  0.8573604060913705
# TP:  810
# FP:  107
# TN:  879
# FN:  174
# Matthews Correlation Coefficient (MCC): 0.7164
# True Positive Rate (TPR): 0.8232
# False Positive Rate (FPR): 0.1085

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Yelp/BERT/flan_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
