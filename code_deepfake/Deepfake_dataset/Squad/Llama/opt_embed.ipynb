# %%
import math
import numpy as np
import os
import pandas as pd
import pickle
from PIL import Image
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer, GPT2Model, pipeline, AutoModelForCausalLM, \
AutoTokenizer, BitsAndBytesConfig, LlamaTokenizer, LlamaModel, AutoModelForTextEncoding
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1,2,3'
model = LlamaModel.from_pretrained("/data/models--meta-llama--Llama-2-13b-chat-hf/snapshots/29655417e51232f4f2b9b5d3e1418e5a9b04e80e")
tokenizer = LlamaTokenizer.from_pretrained("/data/models--meta-llama--Llama-2-13b-chat-hf/snapshots/29655417e51232f4f2b9b5d3e1418e5a9b04e80e")
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'opt' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 6477
# 6477 6477
# 811 811
# 810 810

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
tokenizer.add_special_tokens({'pad_token': '[PAD]'}) 
def generate_bert_embeddings(text):
    input_ids = tokenizer.encode(text, return_tensors='pt',padding=True, truncation=True, max_length=512).to(device) 
    #inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(input_ids)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        #last_hidden_states = outputs.last_hidden_state
        embeddings = outputs.last_hidden_state.mean(dim = 1).squeeze().to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,80,64)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,80,64)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 8098 8098 16196 16196
# /tmp/ipykernel_1027338/1680836081.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch

import torch.nn as nn
import torch.optim as optim

class GPT_CNN2D(nn.Module):
    def __init__(self, embedding_model):
        super(GPT_CNN2D, self).__init__()
        self.em_model = embedding_model
        if embedding_model == "gpt":
            self.conv1 = nn.Conv2d(1, 64, kernel_size=5, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(9120, 128)
            self.fc2 = nn.Linear(128, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()
        elif embedding_model == "mistral":
            self.conv1 = nn.Conv2d(1, 128, kernel_size=5, padding=1, stride = 2)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()            
            self.fc1 = nn.Linear(3136, 512)
            self.fc2 = nn.Linear(512, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        if self.em_model == "gpt":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x
        elif self.em_model == "mistral":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GPT_CNN2D(embedding_model = "gpt").to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.3193
# Validation Accuracy: 0.9401
# TP: 1500, FP: 76, TN: 1546, FN: 118
# Epoch [2/100], Loss: 0.1252
# Validation Accuracy: 0.9531
# TP: 1608, FP: 142, TN: 1480, FN: 10
# Epoch [3/100], Loss: 0.0859
# Validation Accuracy: 0.9630
# TP: 1590, FP: 92, TN: 1530, FN: 28
# Epoch [4/100], Loss: 0.0589
# Validation Accuracy: 0.9506
# TP: 1476, FP: 18, TN: 1604, FN: 142
# Epoch [5/100], Loss: 0.0451
# Validation Accuracy: 0.9685
# TP: 1586, FP: 70, TN: 1552, FN: 32
# Epoch [6/100], Loss: 0.0307
# Validation Accuracy: 0.9725
# TP: 1585, FP: 56, TN: 1566, FN: 33
# Epoch [7/100], Loss: 0.0218
# Validation Accuracy: 0.9673
# TP: 1581, FP: 69, TN: 1553, FN: 37
# Epoch [8/100], Loss: 0.0186
# Validation Accuracy: 0.9679
# TP: 1567, FP: 53, TN: 1569, FN: 51
# Epoch [9/100], Loss: 0.0205
# Validation Accuracy: 0.9642
# TP: 1539, FP: 37, TN: 1585, FN: 79
# Epoch [10/100], Loss: 0.0195
# Validation Accuracy: 0.9651
# TP: 1602, FP: 97, TN: 1525, FN: 16
# Epoch [11/100], Loss: 0.0113
# Validation Accuracy: 0.9651
# TP: 1590, FP: 85, TN: 1537, FN: 28
# Epoch [12/100], Loss: 0.0084
# Validation Accuracy: 0.9673
# TP: 1594, FP: 82, TN: 1540, FN: 24
# Epoch [13/100], Loss: 0.0071
# Validation Accuracy: 0.9497
# TP: 1613, FP: 158, TN: 1464, FN: 5
# Epoch [14/100], Loss: 0.0124
# Validation Accuracy: 0.9691
# TP: 1567, FP: 49, TN: 1573, FN: 51
# Epoch [15/100], Loss: 0.0082
# Validation Accuracy: 0.9679
# TP: 1568, FP: 54, TN: 1568, FN: 50
# Epoch [16/100], Loss: 0.0084
# Validation Accuracy: 0.9627
# TP: 1513, FP: 16, TN: 1606, FN: 105
# Epoch [17/100], Loss: 0.0116
# Validation Accuracy: 0.9716
# TP: 1584, FP: 58, TN: 1564, FN: 34
# Epoch [18/100], Loss: 0.0167
# Validation Accuracy: 0.9691
# TP: 1549, FP: 31, TN: 1591, FN: 69
# Epoch [19/100], Loss: 0.0071
# Validation Accuracy: 0.9660
# TP: 1538, FP: 30, TN: 1592, FN: 80
# Epoch [20/100], Loss: 0.0146
# Validation Accuracy: 0.9651
# TP: 1586, FP: 81, TN: 1541, FN: 32
# Epoch [21/100], Loss: 0.0028
# Validation Accuracy: 0.9673
# TP: 1541, FP: 29, TN: 1593, FN: 77
# Epoch [22/100], Loss: 0.0024
# Validation Accuracy: 0.9642
# TP: 1597, FP: 95, TN: 1527, FN: 21
# Epoch [23/100], Loss: 0.0008
# Validation Accuracy: 0.9698
# TP: 1576, FP: 56, TN: 1566, FN: 42
# Epoch [24/100], Loss: 0.0002
# Validation Accuracy: 0.9725
# TP: 1569, FP: 40, TN: 1582, FN: 49
# Epoch [25/100], Loss: 0.0076
# Validation Accuracy: 0.9645
# TP: 1541, FP: 38, TN: 1584, FN: 77
# Epoch [26/100], Loss: 0.0150
# Validation Accuracy: 0.9667
# TP: 1551, FP: 41, TN: 1581, FN: 67
# Epoch [27/100], Loss: 0.0071
# Validation Accuracy: 0.9716
# TP: 1565, FP: 39, TN: 1583, FN: 53
# Epoch [28/100], Loss: 0.0057
# Validation Accuracy: 0.9694
# TP: 1552, FP: 33, TN: 1589, FN: 66
# Epoch [29/100], Loss: 0.0010
# Validation Accuracy: 0.9679
# TP: 1553, FP: 39, TN: 1583, FN: 65
# Epoch [30/100], Loss: 0.0001
# Validation Accuracy: 0.9707
# TP: 1582, FP: 59, TN: 1563, FN: 36
# Epoch [31/100], Loss: 0.0000
# Validation Accuracy: 0.9701
# TP: 1578, FP: 57, TN: 1565, FN: 40
# Epoch [32/100], Loss: 0.0000
# Validation Accuracy: 0.9704
# TP: 1576, FP: 54, TN: 1568, FN: 42
# Epoch [33/100], Loss: 0.0000
# Validation Accuracy: 0.9704
# TP: 1575, FP: 53, TN: 1569, FN: 43
# Epoch [34/100], Loss: 0.0000
# Validation Accuracy: 0.9698
# TP: 1577, FP: 57, TN: 1565, FN: 41
# Epoch [35/100], Loss: 0.0000
# Validation Accuracy: 0.9707
# TP: 1577, FP: 54, TN: 1568, FN: 41
# Epoch [36/100], Loss: 0.0000
# Validation Accuracy: 0.9707
# TP: 1575, FP: 52, TN: 1570, FN: 43
# Epoch [37/100], Loss: 0.0000
# Validation Accuracy: 0.9704
# TP: 1575, FP: 53, TN: 1569, FN: 43
# Epoch [38/100], Loss: 0.0000
# Validation Accuracy: 0.9707
# TP: 1575, FP: 52, TN: 1570, FN: 43
# Epoch [39/100], Loss: 0.0000
# Validation Accuracy: 0.9707
# TP: 1577, FP: 54, TN: 1568, FN: 41
# Epoch [40/100], Loss: 0.0000
# Validation Accuracy: 0.9698
# TP: 1577, FP: 57, TN: 1565, FN: 41
# Epoch [41/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1576, FP: 52, TN: 1570, FN: 42
# Epoch [42/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1575, FP: 51, TN: 1571, FN: 43
# Epoch [43/100], Loss: 0.0000
# Validation Accuracy: 0.9716
# TP: 1577, FP: 51, TN: 1571, FN: 41
# Epoch [44/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [45/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [46/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [47/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [48/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [49/100], Loss: 0.0000
# Validation Accuracy: 0.9713
# TP: 1577, FP: 52, TN: 1570, FN: 41
# Epoch [50/100], Loss: 0.0000
# Validation Accuracy: 0.9713
# TP: 1577, FP: 52, TN: 1570, FN: 41
# Epoch [51/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [52/100], Loss: 0.0000
# Validation Accuracy: 0.9713
# TP: 1577, FP: 52, TN: 1570, FN: 41
# Epoch [53/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1577, FP: 49, TN: 1573, FN: 41
# Epoch [54/100], Loss: 0.0000
# Validation Accuracy: 0.9713
# TP: 1577, FP: 52, TN: 1570, FN: 41
# Epoch [55/100], Loss: 0.0000
# Validation Accuracy: 0.9710
# TP: 1577, FP: 53, TN: 1569, FN: 41
# Epoch [56/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1577, FP: 49, TN: 1573, FN: 41
# Epoch [57/100], Loss: 0.0000
# Validation Accuracy: 0.9719
# TP: 1577, FP: 50, TN: 1572, FN: 41
# Epoch [58/100], Loss: 0.0000
# Validation Accuracy: 0.9719
# TP: 1577, FP: 50, TN: 1572, FN: 41
# Epoch [59/100], Loss: 0.0000
# Validation Accuracy: 0.9713
# TP: 1579, FP: 54, TN: 1568, FN: 39
# Epoch [60/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1577, FP: 49, TN: 1573, FN: 41
# Epoch [61/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1577, FP: 49, TN: 1573, FN: 41
# Epoch [62/100], Loss: 0.0000
# Validation Accuracy: 0.9716
# TP: 1579, FP: 53, TN: 1569, FN: 39
# Epoch [63/100], Loss: 0.0000
# Validation Accuracy: 0.9719
# TP: 1579, FP: 52, TN: 1570, FN: 39
# Epoch [64/100], Loss: 0.0000
# Validation Accuracy: 0.9725
# TP: 1577, FP: 48, TN: 1574, FN: 41
# Epoch [65/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1577, FP: 49, TN: 1573, FN: 41
# Epoch [66/100], Loss: 0.0000
# Validation Accuracy: 0.9716
# TP: 1580, FP: 54, TN: 1568, FN: 38
# Epoch [67/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1579, FP: 51, TN: 1571, FN: 39
# Epoch [68/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1579, FP: 51, TN: 1571, FN: 39
# Epoch [69/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1580, FP: 52, TN: 1570, FN: 38
# Epoch [70/100], Loss: 0.0000
# Validation Accuracy: 0.9719
# TP: 1580, FP: 53, TN: 1569, FN: 38
# Epoch [71/100], Loss: 0.0000
# Validation Accuracy: 0.9728
# TP: 1579, FP: 49, TN: 1573, FN: 39
# Epoch [72/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1579, FP: 51, TN: 1571, FN: 39
# Epoch [73/100], Loss: 0.0000
# Validation Accuracy: 0.9731
# TP: 1579, FP: 48, TN: 1574, FN: 39
# Epoch [74/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1579, FP: 51, TN: 1571, FN: 39
# Epoch [75/100], Loss: 0.0000
# Validation Accuracy: 0.9725
# TP: 1579, FP: 50, TN: 1572, FN: 39
# Epoch [76/100], Loss: 0.0000
# Validation Accuracy: 0.9722
# TP: 1579, FP: 51, TN: 1571, FN: 39
# Epoch [77/100], Loss: 0.0000
# Validation Accuracy: 0.9725
# TP: 1579, FP: 50, TN: 1572, FN: 39
# Epoch [78/100], Loss: 0.0000
# Validation Accuracy: 0.9728
# TP: 1580, FP: 50, TN: 1572, FN: 38
# Epoch [79/100], Loss: 0.0000
# Validation Accuracy: 0.9741
# TP: 1579, FP: 45, TN: 1577, FN: 39
# Epoch [80/100], Loss: 0.0000
# Validation Accuracy: 0.9728
# TP: 1580, FP: 50, TN: 1572, FN: 38
# Epoch [81/100], Loss: 0.0000
# Validation Accuracy: 0.9728
# TP: 1580, FP: 50, TN: 1572, FN: 38
# Epoch [82/100], Loss: 0.0000
# Validation Accuracy: 0.9731
# TP: 1580, FP: 49, TN: 1573, FN: 38
# Epoch [83/100], Loss: 0.0000
# Validation Accuracy: 0.9731
# TP: 1580, FP: 49, TN: 1573, FN: 38
# Epoch [84/100], Loss: 0.0000
# Validation Accuracy: 0.9735
# TP: 1580, FP: 48, TN: 1574, FN: 38
# Epoch [85/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [86/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [87/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [88/100], Loss: 0.0000
# Validation Accuracy: 0.9735
# TP: 1580, FP: 48, TN: 1574, FN: 38
# Epoch [89/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [90/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [91/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [92/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [93/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [94/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [95/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [96/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [97/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [98/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [99/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38
# Epoch [100/100], Loss: 0.0000
# Validation Accuracy: 0.9738
# TP: 1580, FP: 47, TN: 1575, FN: 38

# %%
print(f"Maximum Validation Accuracy:  {max_val_accuracy:.4f}")
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.3f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.3f}')
print(f'False Positive Rate (FPR): {FPR:.3f}')
# Out:
# Maximum Validation Accuracy:  0.9741
# TP:  1579
# FP:  45
# TN:  1577
# FN:  39
# Matthews Correlation Coefficient (MCC): 0.948
# True Positive Rate (TPR): 0.976
# False Positive Rate (FPR): 0.028

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/Llama/opt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)

# %%
Human_embeddings = Human['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/Llama/human_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, Human_embeddings)
