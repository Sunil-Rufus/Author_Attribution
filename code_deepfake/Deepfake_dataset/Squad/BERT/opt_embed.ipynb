# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer

# Load the model
model_name = "roberta-large"
model = RobertaModel.from_pretrained(model_name)

# Load the tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'opt' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 6477
# 6477 6477
# 811 811
# 810 810

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
def generate_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        last_hidden_states = outputs.last_hidden_state
        embeddings = last_hidden_states[:,0,:].to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,32,32)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,32,32)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 8098 8098 16196 16196
# /tmp/ipykernel_300774/4034461053.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch
import torch.nn as nn
import torch.optim as optim

class CNN(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv2d(8, 2, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # self.conv3 = nn.Conv2d(4, 128, kernel_size=3, stride=1, padding=1)
        # self.relu3 = nn.ReLU()
        # self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(64, 32)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        # x = self.pool3(self.relu3(self.conv3(x)))
        # print(x.shape)
        x = self.flatten(x)
        # print(x.shape)
        x = self.relu4(self.fc1(x))
        x = self.relu5(self.fc2(x))
        x = self.fc3(x) 

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN(in_channels=1, num_classes=2).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.6003
# Validation Accuracy: 0.7907
# TP: 1488, FP: 548, TN: 1074, FN: 130
# Epoch [2/100], Loss: 0.3929
# Validation Accuracy: 0.8525
# TP: 1405, FP: 265, TN: 1357, FN: 213
# Epoch [3/100], Loss: 0.3088
# Validation Accuracy: 0.8738
# TP: 1513, FP: 304, TN: 1318, FN: 105
# Epoch [4/100], Loss: 0.2980
# Validation Accuracy: 0.8802
# TP: 1510, FP: 280, TN: 1342, FN: 108
# Epoch [5/100], Loss: 0.2736
# Validation Accuracy: 0.8781
# TP: 1569, FP: 346, TN: 1276, FN: 49
# Epoch [6/100], Loss: 0.2550
# Validation Accuracy: 0.8833
# TP: 1374, FP: 134, TN: 1488, FN: 244
# Epoch [7/100], Loss: 0.2463
# Validation Accuracy: 0.8941
# TP: 1548, FP: 273, TN: 1349, FN: 70
# Epoch [8/100], Loss: 0.2457
# Validation Accuracy: 0.8787
# TP: 1594, FP: 369, TN: 1253, FN: 24
# Epoch [9/100], Loss: 0.2368
# Validation Accuracy: 0.8951
# TP: 1436, FP: 158, TN: 1464, FN: 182
# Epoch [10/100], Loss: 0.2351
# Validation Accuracy: 0.8944
# TP: 1417, FP: 141, TN: 1481, FN: 201
# Epoch [11/100], Loss: 0.2370
# Validation Accuracy: 0.8969
# TP: 1559, FP: 275, TN: 1347, FN: 59
# Epoch [12/100], Loss: 0.2222
# Validation Accuracy: 0.9043
# TP: 1488, FP: 180, TN: 1442, FN: 130
# Epoch [13/100], Loss: 0.2163
# Validation Accuracy: 0.9043
# TP: 1481, FP: 173, TN: 1449, FN: 137
# Epoch [14/100], Loss: 0.2264
# Validation Accuracy: 0.9056
# TP: 1456, FP: 144, TN: 1478, FN: 162
# Epoch [15/100], Loss: 0.2175
# Validation Accuracy: 0.9043
# TP: 1510, FP: 202, TN: 1420, FN: 108
# Epoch [16/100], Loss: 0.2140
# Validation Accuracy: 0.8972
# TP: 1420, FP: 135, TN: 1487, FN: 198
# Epoch [17/100], Loss: 0.2187
# Validation Accuracy: 0.9090
# TP: 1498, FP: 175, TN: 1447, FN: 120
# Epoch [18/100], Loss: 0.2123
# Validation Accuracy: 0.9111
# TP: 1510, FP: 180, TN: 1442, FN: 108
# Epoch [19/100], Loss: 0.2077
# Validation Accuracy: 0.9080
# TP: 1549, FP: 229, TN: 1393, FN: 69
# Epoch [20/100], Loss: 0.2112
# Validation Accuracy: 0.9123
# TP: 1477, FP: 143, TN: 1479, FN: 141
# Epoch [21/100], Loss: 0.2039
# Validation Accuracy: 0.9130
# TP: 1548, FP: 212, TN: 1410, FN: 70
# Epoch [22/100], Loss: 0.1947
# Validation Accuracy: 0.8985
# TP: 1393, FP: 104, TN: 1518, FN: 225
# Epoch [23/100], Loss: 0.2001
# Validation Accuracy: 0.9083
# TP: 1441, FP: 120, TN: 1502, FN: 177
# Epoch [24/100], Loss: 0.1973
# Validation Accuracy: 0.8951
# TP: 1586, FP: 308, TN: 1314, FN: 32
# Epoch [25/100], Loss: 0.2130
# Validation Accuracy: 0.9077
# TP: 1445, FP: 126, TN: 1496, FN: 173
# Epoch [26/100], Loss: 0.1940
# Validation Accuracy: 0.9127
# TP: 1461, FP: 126, TN: 1496, FN: 157
# Epoch [27/100], Loss: 0.2036
# Validation Accuracy: 0.9194
# TP: 1513, FP: 156, TN: 1466, FN: 105
# Epoch [28/100], Loss: 0.1999
# Validation Accuracy: 0.9164
# TP: 1541, FP: 194, TN: 1428, FN: 77
# Epoch [29/100], Loss: 0.2020
# Validation Accuracy: 0.9133
# TP: 1561, FP: 224, TN: 1398, FN: 57
# Epoch [30/100], Loss: 0.2022
# Validation Accuracy: 0.9198
# TP: 1534, FP: 176, TN: 1446, FN: 84
# Epoch [31/100], Loss: 0.1918
# Validation Accuracy: 0.8892
# TP: 1593, FP: 334, TN: 1288, FN: 25
# Epoch [32/100], Loss: 0.1981
# Validation Accuracy: 0.9102
# TP: 1573, FP: 246, TN: 1376, FN: 45
# Epoch [33/100], Loss: 0.1966
# Validation Accuracy: 0.9176
# TP: 1520, FP: 169, TN: 1453, FN: 98
# Epoch [34/100], Loss: 0.1829
# Validation Accuracy: 0.8988
# TP: 1388, FP: 98, TN: 1524, FN: 230
# Epoch [35/100], Loss: 0.1898
# Validation Accuracy: 0.9117
# TP: 1452, FP: 120, TN: 1502, FN: 166
# Epoch [36/100], Loss: 0.1882
# Validation Accuracy: 0.9074
# TP: 1445, FP: 127, TN: 1495, FN: 173
# Epoch [37/100], Loss: 0.1844
# Validation Accuracy: 0.9219
# TP: 1553, FP: 188, TN: 1434, FN: 65
# Epoch [38/100], Loss: 0.1861
# Validation Accuracy: 0.9102
# TP: 1460, FP: 133, TN: 1489, FN: 158
# Epoch [39/100], Loss: 0.1892
# Validation Accuracy: 0.9188
# TP: 1536, FP: 181, TN: 1441, FN: 82
# Epoch [40/100], Loss: 0.1810
# Validation Accuracy: 0.9139
# TP: 1481, FP: 142, TN: 1480, FN: 137
# Epoch [41/100], Loss: 0.1872
# Validation Accuracy: 0.9157
# TP: 1550, FP: 205, TN: 1417, FN: 68
# Epoch [42/100], Loss: 0.1780
# Validation Accuracy: 0.9151
# TP: 1471, FP: 128, TN: 1494, FN: 147
# Epoch [43/100], Loss: 0.1858
# Validation Accuracy: 0.9188
# TP: 1537, FP: 182, TN: 1440, FN: 81
# Epoch [44/100], Loss: 0.1838
# Validation Accuracy: 0.9012
# TP: 1389, FP: 91, TN: 1531, FN: 229
# Epoch [45/100], Loss: 0.1772
# Validation Accuracy: 0.9213
# TP: 1498, FP: 135, TN: 1487, FN: 120
# Epoch [46/100], Loss: 0.1798
# Validation Accuracy: 0.9191
# TP: 1550, FP: 194, TN: 1428, FN: 68
# Epoch [47/100], Loss: 0.1834
# Validation Accuracy: 0.9204
# TP: 1542, FP: 182, TN: 1440, FN: 76
# Epoch [48/100], Loss: 0.1766
# Validation Accuracy: 0.8772
# TP: 1280, FP: 60, TN: 1562, FN: 338
# Epoch [49/100], Loss: 0.1719
# Validation Accuracy: 0.9074
# TP: 1578, FP: 260, TN: 1362, FN: 40
# Epoch [50/100], Loss: 0.1723
# Validation Accuracy: 0.9222
# TP: 1538, FP: 172, TN: 1450, FN: 80
# Epoch [51/100], Loss: 0.1731
# Validation Accuracy: 0.9198
# TP: 1508, FP: 150, TN: 1472, FN: 110
# Epoch [52/100], Loss: 0.1780
# Validation Accuracy: 0.9133
# TP: 1547, FP: 210, TN: 1412, FN: 71
# Epoch [53/100], Loss: 0.1755
# Validation Accuracy: 0.9170
# TP: 1496, FP: 147, TN: 1475, FN: 122
# Epoch [54/100], Loss: 0.1704
# Validation Accuracy: 0.9096
# TP: 1430, FP: 105, TN: 1517, FN: 188
# Epoch [55/100], Loss: 0.1732
# Validation Accuracy: 0.8972
# TP: 1585, FP: 300, TN: 1322, FN: 33
# Epoch [56/100], Loss: 0.1715
# Validation Accuracy: 0.9080
# TP: 1420, FP: 100, TN: 1522, FN: 198
# Epoch [57/100], Loss: 0.1661
# Validation Accuracy: 0.9210
# TP: 1565, FP: 203, TN: 1419, FN: 53
# Epoch [58/100], Loss: 0.1710
# Validation Accuracy: 0.9210
# TP: 1533, FP: 171, TN: 1451, FN: 85
# Epoch [59/100], Loss: 0.1611
# Validation Accuracy: 0.9222
# TP: 1549, FP: 183, TN: 1439, FN: 69
# Epoch [60/100], Loss: 0.1631
# Validation Accuracy: 0.9176
# TP: 1460, FP: 109, TN: 1513, FN: 158
# Epoch [61/100], Loss: 0.1629
# Validation Accuracy: 0.9139
# TP: 1568, FP: 229, TN: 1393, FN: 50
# Epoch [62/100], Loss: 0.1690
# Validation Accuracy: 0.9222
# TP: 1518, FP: 152, TN: 1470, FN: 100
# Epoch [63/100], Loss: 0.1679
# Validation Accuracy: 0.9105
# TP: 1575, FP: 247, TN: 1375, FN: 43
# Epoch [64/100], Loss: 0.1750
# Validation Accuracy: 0.9216
# TP: 1493, FP: 129, TN: 1493, FN: 125
# Epoch [65/100], Loss: 0.1569
# Validation Accuracy: 0.9241
# TP: 1537, FP: 165, TN: 1457, FN: 81
# Epoch [66/100], Loss: 0.1641
# Validation Accuracy: 0.9256
# TP: 1508, FP: 131, TN: 1491, FN: 110
# Epoch [67/100], Loss: 0.1570
# Validation Accuracy: 0.9247
# TP: 1540, FP: 166, TN: 1456, FN: 78
# Epoch [68/100], Loss: 0.1566
# Validation Accuracy: 0.9225
# TP: 1550, FP: 183, TN: 1439, FN: 68
# Epoch [69/100], Loss: 0.1598
# Validation Accuracy: 0.9207
# TP: 1548, FP: 187, TN: 1435, FN: 70
# Epoch [70/100], Loss: 0.1551
# Validation Accuracy: 0.9154
# TP: 1445, FP: 101, TN: 1521, FN: 173
# Epoch [71/100], Loss: 0.1555
# Validation Accuracy: 0.9154
# TP: 1575, FP: 231, TN: 1391, FN: 43
# Epoch [72/100], Loss: 0.1629
# Validation Accuracy: 0.9244
# TP: 1487, FP: 114, TN: 1508, FN: 131
# Epoch [73/100], Loss: 0.1604
# Validation Accuracy: 0.9247
# TP: 1502, FP: 128, TN: 1494, FN: 116
# Epoch [74/100], Loss: 0.1574
# Validation Accuracy: 0.9170
# TP: 1457, FP: 108, TN: 1514, FN: 161
# Epoch [75/100], Loss: 0.1541
# Validation Accuracy: 0.9256
# TP: 1501, FP: 124, TN: 1498, FN: 117
# Epoch [76/100], Loss: 0.1512
# Validation Accuracy: 0.9244
# TP: 1547, FP: 174, TN: 1448, FN: 71
# Epoch [77/100], Loss: 0.1475
# Validation Accuracy: 0.9114
# TP: 1584, FP: 253, TN: 1369, FN: 34
# Epoch [78/100], Loss: 0.1547
# Validation Accuracy: 0.9170
# TP: 1573, FP: 224, TN: 1398, FN: 45
# Epoch [79/100], Loss: 0.1523
# Validation Accuracy: 0.9213
# TP: 1479, FP: 116, TN: 1506, FN: 139
# Epoch [80/100], Loss: 0.1480
# Validation Accuracy: 0.9207
# TP: 1490, FP: 129, TN: 1493, FN: 128
# Epoch [81/100], Loss: 0.1557
# Validation Accuracy: 0.9262
# TP: 1512, FP: 133, TN: 1489, FN: 106
# Epoch [82/100], Loss: 0.1500
# Validation Accuracy: 0.9231
# TP: 1559, FP: 190, TN: 1432, FN: 59
# Epoch [83/100], Loss: 0.1461
# Validation Accuracy: 0.9262
# TP: 1532, FP: 153, TN: 1469, FN: 86
# Epoch [84/100], Loss: 0.1486
# Validation Accuracy: 0.9185
# TP: 1454, FP: 100, TN: 1522, FN: 164
# Epoch [85/100], Loss: 0.1472
# Validation Accuracy: 0.9207
# TP: 1470, FP: 109, TN: 1513, FN: 148
# Epoch [86/100], Loss: 0.1480
# Validation Accuracy: 0.9238
# TP: 1497, FP: 126, TN: 1496, FN: 121
# Epoch [87/100], Loss: 0.1506
# Validation Accuracy: 0.9111
# TP: 1422, FP: 92, TN: 1530, FN: 196
# Epoch [88/100], Loss: 0.1437
# Validation Accuracy: 0.9179
# TP: 1458, FP: 106, TN: 1516, FN: 160
# Epoch [89/100], Loss: 0.1435
# Validation Accuracy: 0.9259
# TP: 1511, FP: 133, TN: 1489, FN: 107
# Epoch [90/100], Loss: 0.1456
# Validation Accuracy: 0.8917
# TP: 1596, FP: 329, TN: 1293, FN: 22
# Epoch [91/100], Loss: 0.1441
# Validation Accuracy: 0.9185
# TP: 1459, FP: 105, TN: 1517, FN: 159
# Epoch [92/100], Loss: 0.1439
# Validation Accuracy: 0.9182
# TP: 1449, FP: 96, TN: 1526, FN: 169
# Epoch [93/100], Loss: 0.1480
# Validation Accuracy: 0.9259
# TP: 1511, FP: 133, TN: 1489, FN: 107
# Epoch [94/100], Loss: 0.1405
# Validation Accuracy: 0.9275
# TP: 1537, FP: 154, TN: 1468, FN: 81
# Epoch [95/100], Loss: 0.1379
# Validation Accuracy: 0.9207
# TP: 1560, FP: 199, TN: 1423, FN: 58
# Epoch [96/100], Loss: 0.1432
# Validation Accuracy: 0.9130
# TP: 1581, FP: 245, TN: 1377, FN: 37
# Epoch [97/100], Loss: 0.1398
# Validation Accuracy: 0.9117
# TP: 1424, FP: 92, TN: 1530, FN: 194
# Epoch [98/100], Loss: 0.1419
# Validation Accuracy: 0.9228
# TP: 1491, FP: 123, TN: 1499, FN: 127
# Epoch [99/100], Loss: 0.1374
# Validation Accuracy: 0.9188
# TP: 1561, FP: 206, TN: 1416, FN: 57
# Epoch [100/100], Loss: 0.1348
# Validation Accuracy: 0.9247
# TP: 1517, FP: 143, TN: 1479, FN: 101

# %%
print("Maximum Validation Accuracy: ", max_val_accuracy)
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.4f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.4f}')
print(f'False Positive Rate (FPR): {FPR:.4f}')
# Out:
# Maximum Validation Accuracy:  0.9274691358024691
# TP:  1537
# FP:  154
# TN:  1468
# FN:  81
# Matthews Correlation Coefficient (MCC): 0.8558
# True Positive Rate (TPR): 0.9499
# False Positive Rate (FPR): 0.0949

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Squad/BERT/opt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
