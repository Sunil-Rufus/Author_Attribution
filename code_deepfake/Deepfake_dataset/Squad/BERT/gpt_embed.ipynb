# %%
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer

# Load the model
model_name = "roberta-large"
model = RobertaModel.from_pretrained(model_name)

# Load the tokenizer
tokenizer = RobertaTokenizer.from_pretrained(model_name)
from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'gpt' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'gpt' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'gpt' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 1830
# 1830 1830
# 228 228
# 220 220

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
def generate_bert_embeddings(text):
    inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)
    inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(**inputs)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        last_hidden_states = outputs.last_hidden_state
        embeddings = last_hidden_states[:,0,:].to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,32,32)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,32,32)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# /tmp/ipykernel_299015/4034461053.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 2278 2278 4556 4556

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch
import torch.nn as nn
import torch.optim as optim

class CNN(nn.Module):
    def __init__(self, in_channels, num_classes):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels, 8, kernel_size=3, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv2d(8, 2, kernel_size=3, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        # self.conv3 = nn.Conv2d(4, 128, kernel_size=3, stride=1, padding=1)
        # self.relu3 = nn.ReLU()
        # self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.flatten = nn.Flatten()

        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU()

        self.fc2 = nn.Linear(64, 32)
        self.relu5 = nn.ReLU()

        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = self.pool1(self.relu1(self.conv1(x)))
        x = self.pool2(self.relu2(self.conv2(x)))
        # x = self.pool3(self.relu3(self.conv3(x)))
        # print(x.shape)
        x = self.flatten(x)
        # print(x.shape)
        x = self.relu4(self.fc1(x))
        x = self.relu5(self.fc2(x))
        x = self.fc3(x) 

        return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN(in_channels=1, num_classes=2).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.6914
# Validation Accuracy: 0.5164
# TP: 424, FP: 426, TN: 47, FN: 15
# Epoch [2/100], Loss: 0.6498
# Validation Accuracy: 0.6743
# TP: 290, FP: 148, TN: 325, FN: 149
# Epoch [3/100], Loss: 0.5797
# Validation Accuracy: 0.7018
# TP: 392, FP: 225, TN: 248, FN: 47
# Epoch [4/100], Loss: 0.5466
# Validation Accuracy: 0.7314
# TP: 396, FP: 202, TN: 271, FN: 43
# Epoch [5/100], Loss: 0.5062
# Validation Accuracy: 0.7336
# TP: 294, FP: 98, TN: 375, FN: 145
# Epoch [6/100], Loss: 0.4776
# Validation Accuracy: 0.7566
# TP: 400, FP: 183, TN: 290, FN: 39
# Epoch [7/100], Loss: 0.4761
# Validation Accuracy: 0.7708
# TP: 392, FP: 162, TN: 311, FN: 47
# Epoch [8/100], Loss: 0.4370
# Validation Accuracy: 0.7917
# TP: 366, FP: 117, TN: 356, FN: 73
# Epoch [9/100], Loss: 0.4134
# Validation Accuracy: 0.7851
# TP: 320, FP: 77, TN: 396, FN: 119
# Epoch [10/100], Loss: 0.4052
# Validation Accuracy: 0.8004
# TP: 380, FP: 123, TN: 350, FN: 59
# Epoch [11/100], Loss: 0.3977
# Validation Accuracy: 0.7939
# TP: 388, FP: 137, TN: 336, FN: 51
# Epoch [12/100], Loss: 0.3783
# Validation Accuracy: 0.8103
# TP: 374, FP: 108, TN: 365, FN: 65
# Epoch [13/100], Loss: 0.3810
# Validation Accuracy: 0.8070
# TP: 408, FP: 145, TN: 328, FN: 31
# Epoch [14/100], Loss: 0.3543
# Validation Accuracy: 0.8180
# TP: 381, FP: 108, TN: 365, FN: 58
# Epoch [15/100], Loss: 0.3533
# Validation Accuracy: 0.8026
# TP: 317, FP: 58, TN: 415, FN: 122
# Epoch [16/100], Loss: 0.3370
# Validation Accuracy: 0.8202
# TP: 405, FP: 130, TN: 343, FN: 34
# Epoch [17/100], Loss: 0.3425
# Validation Accuracy: 0.7982
# TP: 310, FP: 55, TN: 418, FN: 129
# Epoch [18/100], Loss: 0.3393
# Validation Accuracy: 0.8246
# TP: 341, FP: 62, TN: 411, FN: 98
# Epoch [19/100], Loss: 0.3295
# Validation Accuracy: 0.8136
# TP: 318, FP: 49, TN: 424, FN: 121
# Epoch [20/100], Loss: 0.3892
# Validation Accuracy: 0.8432
# TP: 371, FP: 75, TN: 398, FN: 68
# Epoch [21/100], Loss: 0.3236
# Validation Accuracy: 0.8355
# TP: 393, FP: 104, TN: 369, FN: 46
# Epoch [22/100], Loss: 0.3154
# Validation Accuracy: 0.8421
# TP: 356, FP: 61, TN: 412, FN: 83
# Epoch [23/100], Loss: 0.3116
# Validation Accuracy: 0.8311
# TP: 403, FP: 118, TN: 355, FN: 36
# Epoch [24/100], Loss: 0.3245
# Validation Accuracy: 0.8421
# TP: 358, FP: 63, TN: 410, FN: 81
# Epoch [25/100], Loss: 0.3145
# Validation Accuracy: 0.8366
# TP: 348, FP: 58, TN: 415, FN: 91
# Epoch [26/100], Loss: 0.3065
# Validation Accuracy: 0.8498
# TP: 397, FP: 95, TN: 378, FN: 42
# Epoch [27/100], Loss: 0.2898
# Validation Accuracy: 0.8399
# TP: 350, FP: 57, TN: 416, FN: 89
# Epoch [28/100], Loss: 0.2934
# Validation Accuracy: 0.8333
# TP: 404, FP: 117, TN: 356, FN: 35
# Epoch [29/100], Loss: 0.3159
# Validation Accuracy: 0.8421
# TP: 367, FP: 72, TN: 401, FN: 72
# Epoch [30/100], Loss: 0.2844
# Validation Accuracy: 0.8520
# TP: 377, FP: 73, TN: 400, FN: 62
# Epoch [31/100], Loss: 0.2982
# Validation Accuracy: 0.8410
# TP: 355, FP: 61, TN: 412, FN: 84
# Epoch [32/100], Loss: 0.2894
# Validation Accuracy: 0.8564
# TP: 377, FP: 69, TN: 404, FN: 62
# Epoch [33/100], Loss: 0.2762
# Validation Accuracy: 0.8553
# TP: 397, FP: 90, TN: 383, FN: 42
# Epoch [34/100], Loss: 0.2808
# Validation Accuracy: 0.8542
# TP: 375, FP: 69, TN: 404, FN: 64
# Epoch [35/100], Loss: 0.2705
# Validation Accuracy: 0.8487
# TP: 384, FP: 83, TN: 390, FN: 55
# Epoch [36/100], Loss: 0.2849
# Validation Accuracy: 0.8158
# TP: 309, FP: 38, TN: 435, FN: 130
# Epoch [37/100], Loss: 0.2692
# Validation Accuracy: 0.8366
# TP: 348, FP: 58, TN: 415, FN: 91
# Epoch [38/100], Loss: 0.2789
# Validation Accuracy: 0.8607
# TP: 384, FP: 72, TN: 401, FN: 55
# Epoch [39/100], Loss: 0.2716
# Validation Accuracy: 0.8487
# TP: 361, FP: 60, TN: 413, FN: 78
# Epoch [40/100], Loss: 0.2678
# Validation Accuracy: 0.8498
# TP: 410, FP: 108, TN: 365, FN: 29
# Epoch [41/100], Loss: 0.2579
# Validation Accuracy: 0.8564
# TP: 383, FP: 75, TN: 398, FN: 56
# Epoch [42/100], Loss: 0.2557
# Validation Accuracy: 0.8531
# TP: 389, FP: 84, TN: 389, FN: 50
# Epoch [43/100], Loss: 0.2624
# Validation Accuracy: 0.8618
# TP: 389, FP: 76, TN: 397, FN: 50
# Epoch [44/100], Loss: 0.2577
# Validation Accuracy: 0.8531
# TP: 359, FP: 54, TN: 419, FN: 80
# Epoch [45/100], Loss: 0.2573
# Validation Accuracy: 0.8596
# TP: 383, FP: 72, TN: 401, FN: 56
# Epoch [46/100], Loss: 0.2444
# Validation Accuracy: 0.8531
# TP: 363, FP: 58, TN: 415, FN: 76
# Epoch [47/100], Loss: 0.2769
# Validation Accuracy: 0.8432
# TP: 410, FP: 114, TN: 359, FN: 29
# Epoch [48/100], Loss: 0.2465
# Validation Accuracy: 0.8695
# TP: 384, FP: 64, TN: 409, FN: 55
# Epoch [49/100], Loss: 0.2483
# Validation Accuracy: 0.8662
# TP: 390, FP: 73, TN: 400, FN: 49
# Epoch [50/100], Loss: 0.2485
# Validation Accuracy: 0.8531
# TP: 371, FP: 66, TN: 407, FN: 68
# Epoch [51/100], Loss: 0.2394
# Validation Accuracy: 0.8673
# TP: 391, FP: 73, TN: 400, FN: 48
# Epoch [52/100], Loss: 0.2417
# Validation Accuracy: 0.8629
# TP: 394, FP: 80, TN: 393, FN: 45
# Epoch [53/100], Loss: 0.2311
# Validation Accuracy: 0.8651
# TP: 395, FP: 79, TN: 394, FN: 44
# Epoch [54/100], Loss: 0.2368
# Validation Accuracy: 0.8575
# TP: 362, FP: 53, TN: 420, FN: 77
# Epoch [55/100], Loss: 0.2525
# Validation Accuracy: 0.8662
# TP: 387, FP: 70, TN: 403, FN: 52
# Epoch [56/100], Loss: 0.2478
# Validation Accuracy: 0.8629
# TP: 372, FP: 58, TN: 415, FN: 67
# Epoch [57/100], Loss: 0.2362
# Validation Accuracy: 0.8575
# TP: 363, FP: 54, TN: 419, FN: 76
# Epoch [58/100], Loss: 0.2555
# Validation Accuracy: 0.8586
# TP: 381, FP: 71, TN: 402, FN: 58
# Epoch [59/100], Loss: 0.2259
# Validation Accuracy: 0.8575
# TP: 372, FP: 63, TN: 410, FN: 67
# Epoch [60/100], Loss: 0.2261
# Validation Accuracy: 0.8531
# TP: 393, FP: 88, TN: 385, FN: 46
# Epoch [61/100], Loss: 0.2212
# Validation Accuracy: 0.8651
# TP: 373, FP: 57, TN: 416, FN: 66
# Epoch [62/100], Loss: 0.2260
# Validation Accuracy: 0.8564
# TP: 359, FP: 51, TN: 422, FN: 80
# Epoch [63/100], Loss: 0.2391
# Validation Accuracy: 0.8531
# TP: 351, FP: 46, TN: 427, FN: 88
# Epoch [64/100], Loss: 0.2347
# Validation Accuracy: 0.8531
# TP: 351, FP: 46, TN: 427, FN: 88
# Epoch [65/100], Loss: 0.2233
# Validation Accuracy: 0.8575
# TP: 398, FP: 89, TN: 384, FN: 41
# Epoch [66/100], Loss: 0.2316
# Validation Accuracy: 0.8618
# TP: 382, FP: 69, TN: 404, FN: 57
# Epoch [67/100], Loss: 0.2271
# Validation Accuracy: 0.8586
# TP: 373, FP: 63, TN: 410, FN: 66
# Epoch [68/100], Loss: 0.2112
# Validation Accuracy: 0.8531
# TP: 358, FP: 53, TN: 420, FN: 81
# Epoch [69/100], Loss: 0.2249
# Validation Accuracy: 0.8651
# TP: 381, FP: 65, TN: 408, FN: 58
# Epoch [70/100], Loss: 0.2106
# Validation Accuracy: 0.8498
# TP: 345, FP: 43, TN: 430, FN: 94
# Epoch [71/100], Loss: 0.2116
# Validation Accuracy: 0.8487
# TP: 354, FP: 53, TN: 420, FN: 85
# Epoch [72/100], Loss: 0.2130
# Validation Accuracy: 0.8300
# TP: 325, FP: 41, TN: 432, FN: 114
# Epoch [73/100], Loss: 0.2153
# Validation Accuracy: 0.8465
# TP: 414, FP: 115, TN: 358, FN: 25
# Epoch [74/100], Loss: 0.2073
# Validation Accuracy: 0.8662
# TP: 373, FP: 56, TN: 417, FN: 66
# Epoch [75/100], Loss: 0.2111
# Validation Accuracy: 0.8553
# TP: 383, FP: 76, TN: 397, FN: 56
# Epoch [76/100], Loss: 0.2036
# Validation Accuracy: 0.8596
# TP: 388, FP: 77, TN: 396, FN: 51
# Epoch [77/100], Loss: 0.2042
# Validation Accuracy: 0.8421
# TP: 331, FP: 36, TN: 437, FN: 108
# Epoch [78/100], Loss: 0.2147
# Validation Accuracy: 0.8564
# TP: 401, FP: 93, TN: 380, FN: 38
# Epoch [79/100], Loss: 0.1970
# Validation Accuracy: 0.8607
# TP: 383, FP: 71, TN: 402, FN: 56
# Epoch [80/100], Loss: 0.1951
# Validation Accuracy: 0.8487
# TP: 406, FP: 105, TN: 368, FN: 33
# Epoch [81/100], Loss: 0.2043
# Validation Accuracy: 0.8542
# TP: 356, FP: 50, TN: 423, FN: 83
# Epoch [82/100], Loss: 0.2185
# Validation Accuracy: 0.8629
# TP: 365, FP: 51, TN: 422, FN: 74
# Epoch [83/100], Loss: 0.2159
# Validation Accuracy: 0.8629
# TP: 373, FP: 59, TN: 414, FN: 66
# Epoch [84/100], Loss: 0.2063
# Validation Accuracy: 0.8618
# TP: 368, FP: 55, TN: 418, FN: 71
# Epoch [85/100], Loss: 0.1927
# Validation Accuracy: 0.8564
# TP: 360, FP: 52, TN: 421, FN: 79
# Epoch [86/100], Loss: 0.1944
# Validation Accuracy: 0.8596
# TP: 374, FP: 63, TN: 410, FN: 65
# Epoch [87/100], Loss: 0.1935
# Validation Accuracy: 0.8399
# TP: 328, FP: 35, TN: 438, FN: 111
# Epoch [88/100], Loss: 0.2129
# Validation Accuracy: 0.8553
# TP: 358, FP: 51, TN: 422, FN: 81
# Epoch [89/100], Loss: 0.1978
# Validation Accuracy: 0.8564
# TP: 392, FP: 84, TN: 389, FN: 47
# Epoch [90/100], Loss: 0.1887
# Validation Accuracy: 0.8586
# TP: 385, FP: 75, TN: 398, FN: 54
# Epoch [91/100], Loss: 0.1938
# Validation Accuracy: 0.8728
# TP: 377, FP: 54, TN: 419, FN: 62
# Epoch [92/100], Loss: 0.1855
# Validation Accuracy: 0.8531
# TP: 405, FP: 100, TN: 373, FN: 34
# Epoch [93/100], Loss: 0.1878
# Validation Accuracy: 0.8586
# TP: 392, FP: 82, TN: 391, FN: 47
# Epoch [94/100], Loss: 0.1860
# Validation Accuracy: 0.8607
# TP: 395, FP: 83, TN: 390, FN: 44
# Epoch [95/100], Loss: 0.1964
# Validation Accuracy: 0.8662
# TP: 387, FP: 70, TN: 403, FN: 52
# Epoch [96/100], Loss: 0.1903
# Validation Accuracy: 0.8564
# TP: 397, FP: 89, TN: 384, FN: 42
# Epoch [97/100], Loss: 0.1791
# Validation Accuracy: 0.8651
# TP: 380, FP: 64, TN: 409, FN: 59
# Epoch [98/100], Loss: 0.1835
# Validation Accuracy: 0.8575
# TP: 405, FP: 96, TN: 377, FN: 34
# Epoch [99/100], Loss: 0.1789
# Validation Accuracy: 0.8586
# TP: 366, FP: 56, TN: 417, FN: 73
# Epoch [100/100], Loss: 0.1786
# Validation Accuracy: 0.8717
# TP: 385, FP: 63, TN: 410, FN: 54

# %%
print("Maximum Validation Accuracy: ", max_val_accuracy)
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.4f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.4f}')
print(f'False Positive Rate (FPR): {FPR:.4f}')
# Out:
# Maximum Validation Accuracy:  0.8728070175438597
# TP:  377
# FP:  54
# TN:  419
# FN:  62
# Matthews Correlation Coefficient (MCC): 0.7452
# True Positive Rate (TPR): 0.8588
# False Positive Rate (FPR): 0.1142

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Squad/BERT/gpt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)

# %%
Human_embeddings = Human['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code/Deepfake_dataset/Squad/BERT/human_embeddings.npy', 'wb') as f:
    #for i in range(len(human['embeddings'])):
    np.save(f, Human_embeddings)
