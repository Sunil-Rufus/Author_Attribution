# %%
import math
import numpy as np
import os
import pandas as pd
import pickle
from PIL import Image
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer, GPT2Model, pipeline, AutoModelForCausalLM, \
AutoTokenizer, BitsAndBytesConfig, LlamaTokenizer, LlamaModel, AutoModelForTextEncoding
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2') 

from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'opt' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'opt' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 6477
# 6477 6477
# 811 811
# 810 810

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
tokenizer.add_special_tokens({'pad_token': '[PAD]'}) 
def generate_bert_embeddings(text):
    input_ids = tokenizer.encode(text, return_tensors='pt',padding=True, truncation=True, max_length=512).to(device) 
    #inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(input_ids)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        #last_hidden_states = outputs.last_hidden_state
        embeddings = outputs.last_hidden_state.mean(dim = 1).squeeze().to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,16,48)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,16,48)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 8098 8098 16196 16196
# /tmp/ipykernel_384390/3934376841.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch

import torch.nn as nn
import torch.optim as optim

class GPT_CNN2D(nn.Module):
    def __init__(self, embedding_model):
        super(GPT_CNN2D, self).__init__()
        self.em_model = embedding_model
        if embedding_model == "gpt":
            self.conv1 = nn.Conv2d(1, 64, kernel_size=5, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(1056, 128)
            self.fc2 = nn.Linear(128, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()
        elif embedding_model == "mistral":
            self.conv1 = nn.Conv2d(1, 128, kernel_size=5, padding=1, stride = 2)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()            
            self.fc1 = nn.Linear(3136, 512)
            self.fc2 = nn.Linear(512, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        if self.em_model == "gpt":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x
        elif self.em_model == "mistral":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GPT_CNN2D(embedding_model = "gpt").to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.7095
# Validation Accuracy: 0.6191
# TP: 1061, FP: 677, TN: 945, FN: 557
# Epoch [2/100], Loss: 0.6381
# Validation Accuracy: 0.6830
# TP: 1175, FP: 584, TN: 1038, FN: 443
# Epoch [3/100], Loss: 0.5186
# Validation Accuracy: 0.8198
# TP: 1333, FP: 299, TN: 1323, FN: 285
# Epoch [4/100], Loss: 0.3898
# Validation Accuracy: 0.7472
# TP: 1580, FP: 781, TN: 841, FN: 38
# Epoch [5/100], Loss: 0.3279
# Validation Accuracy: 0.8682
# TP: 1455, FP: 264, TN: 1358, FN: 163
# Epoch [6/100], Loss: 0.2836
# Validation Accuracy: 0.8796
# TP: 1477, FP: 249, TN: 1373, FN: 141
# Epoch [7/100], Loss: 0.2620
# Validation Accuracy: 0.8873
# TP: 1456, FP: 203, TN: 1419, FN: 162
# Epoch [8/100], Loss: 0.2397
# Validation Accuracy: 0.8923
# TP: 1455, FP: 186, TN: 1436, FN: 163
# Epoch [9/100], Loss: 0.2295
# Validation Accuracy: 0.8833
# TP: 1328, FP: 88, TN: 1534, FN: 290
# Epoch [10/100], Loss: 0.2095
# Validation Accuracy: 0.9015
# TP: 1504, FP: 205, TN: 1417, FN: 114
# Epoch [11/100], Loss: 0.2185
# Validation Accuracy: 0.8883
# TP: 1346, FP: 90, TN: 1532, FN: 272
# Epoch [12/100], Loss: 0.1957
# Validation Accuracy: 0.9034
# TP: 1446, FP: 141, TN: 1481, FN: 172
# Epoch [13/100], Loss: 0.1930
# Validation Accuracy: 0.9105
# TP: 1460, FP: 132, TN: 1490, FN: 158
# Epoch [14/100], Loss: 0.1740
# Validation Accuracy: 0.9111
# TP: 1450, FP: 120, TN: 1502, FN: 168
# Epoch [15/100], Loss: 0.1691
# Validation Accuracy: 0.9040
# TP: 1496, FP: 189, TN: 1433, FN: 122
# Epoch [16/100], Loss: 0.1653
# Validation Accuracy: 0.8997
# TP: 1520, FP: 227, TN: 1395, FN: 98
# Epoch [17/100], Loss: 0.1539
# Validation Accuracy: 0.9065
# TP: 1495, FP: 180, TN: 1442, FN: 123
# Epoch [18/100], Loss: 0.1583
# Validation Accuracy: 0.9117
# TP: 1501, FP: 169, TN: 1453, FN: 117
# Epoch [19/100], Loss: 0.1539
# Validation Accuracy: 0.8627
# TP: 1579, FP: 406, TN: 1216, FN: 39
# Epoch [20/100], Loss: 0.1540
# Validation Accuracy: 0.9108
# TP: 1509, FP: 180, TN: 1442, FN: 109
# Epoch [21/100], Loss: 0.1350
# Validation Accuracy: 0.9093
# TP: 1415, FP: 91, TN: 1531, FN: 203
# Epoch [22/100], Loss: 0.1527
# Validation Accuracy: 0.9151
# TP: 1489, FP: 146, TN: 1476, FN: 129
# Epoch [23/100], Loss: 0.1406
# Validation Accuracy: 0.9077
# TP: 1410, FP: 91, TN: 1531, FN: 208
# Epoch [24/100], Loss: 0.1377
# Validation Accuracy: 0.9105
# TP: 1517, FP: 189, TN: 1433, FN: 101
# Epoch [25/100], Loss: 0.1298
# Validation Accuracy: 0.9148
# TP: 1465, FP: 123, TN: 1499, FN: 153
# Epoch [26/100], Loss: 0.1331
# Validation Accuracy: 0.9052
# TP: 1531, FP: 220, TN: 1402, FN: 87
# Epoch [27/100], Loss: 0.1324
# Validation Accuracy: 0.9099
# TP: 1507, FP: 181, TN: 1441, FN: 111
# Epoch [28/100], Loss: 0.1292
# Validation Accuracy: 0.9090
# TP: 1449, FP: 126, TN: 1496, FN: 169
# Epoch [29/100], Loss: 0.1204
# Validation Accuracy: 0.9145
# TP: 1433, FP: 92, TN: 1530, FN: 185
# Epoch [30/100], Loss: 0.1287
# Validation Accuracy: 0.9102
# TP: 1511, FP: 184, TN: 1438, FN: 107
# Epoch [31/100], Loss: 0.1131
# Validation Accuracy: 0.9120
# TP: 1480, FP: 147, TN: 1475, FN: 138
# Epoch [32/100], Loss: 0.1225
# Validation Accuracy: 0.9136
# TP: 1452, FP: 114, TN: 1508, FN: 166
# Epoch [33/100], Loss: 0.1026
# Validation Accuracy: 0.9164
# TP: 1467, FP: 120, TN: 1502, FN: 151
# Epoch [34/100], Loss: 0.1072
# Validation Accuracy: 0.9000
# TP: 1540, FP: 246, TN: 1376, FN: 78
# Epoch [35/100], Loss: 0.1079
# Validation Accuracy: 0.9170
# TP: 1457, FP: 108, TN: 1514, FN: 161
# Epoch [36/100], Loss: 0.0999
# Validation Accuracy: 0.9120
# TP: 1517, FP: 184, TN: 1438, FN: 101
# Epoch [37/100], Loss: 0.0923
# Validation Accuracy: 0.8886
# TP: 1562, FP: 305, TN: 1317, FN: 56
# Epoch [38/100], Loss: 0.1259
# Validation Accuracy: 0.9071
# TP: 1423, FP: 106, TN: 1516, FN: 195
# Epoch [39/100], Loss: 0.1081
# Validation Accuracy: 0.9111
# TP: 1473, FP: 143, TN: 1479, FN: 145
# Epoch [40/100], Loss: 0.0938
# Validation Accuracy: 0.9068
# TP: 1515, FP: 199, TN: 1423, FN: 103
# Epoch [41/100], Loss: 0.0938
# Validation Accuracy: 0.9043
# TP: 1530, FP: 222, TN: 1400, FN: 88
# Epoch [42/100], Loss: 0.0891
# Validation Accuracy: 0.9086
# TP: 1407, FP: 85, TN: 1537, FN: 211
# Epoch [43/100], Loss: 0.0842
# Validation Accuracy: 0.9096
# TP: 1418, FP: 93, TN: 1529, FN: 200
# Epoch [44/100], Loss: 0.0912
# Validation Accuracy: 0.9019
# TP: 1376, FP: 76, TN: 1546, FN: 242
# Epoch [45/100], Loss: 0.0912
# Validation Accuracy: 0.9133
# TP: 1476, FP: 139, TN: 1483, FN: 142
# Epoch [46/100], Loss: 0.0837
# Validation Accuracy: 0.9090
# TP: 1495, FP: 172, TN: 1450, FN: 123
# Epoch [47/100], Loss: 0.0930
# Validation Accuracy: 0.9127
# TP: 1432, FP: 97, TN: 1525, FN: 186
# Epoch [48/100], Loss: 0.0813
# Validation Accuracy: 0.9167
# TP: 1483, FP: 135, TN: 1487, FN: 135
# Epoch [49/100], Loss: 0.0735
# Validation Accuracy: 0.9111
# TP: 1441, FP: 111, TN: 1511, FN: 177
# Epoch [50/100], Loss: 0.0896
# Validation Accuracy: 0.9074
# TP: 1447, FP: 129, TN: 1493, FN: 171
# Epoch [51/100], Loss: 0.0824
# Validation Accuracy: 0.9059
# TP: 1500, FP: 187, TN: 1435, FN: 118
# Epoch [52/100], Loss: 0.0860
# Validation Accuracy: 0.9080
# TP: 1512, FP: 192, TN: 1430, FN: 106
# Epoch [53/100], Loss: 0.0710
# Validation Accuracy: 0.9071
# TP: 1496, FP: 179, TN: 1443, FN: 122
# Epoch [54/100], Loss: 0.0626
# Validation Accuracy: 0.9130
# TP: 1490, FP: 154, TN: 1468, FN: 128
# Epoch [55/100], Loss: 0.0685
# Validation Accuracy: 0.9083
# TP: 1483, FP: 162, TN: 1460, FN: 135
# Epoch [56/100], Loss: 0.0737
# Validation Accuracy: 0.9111
# TP: 1451, FP: 121, TN: 1501, FN: 167
# Epoch [57/100], Loss: 0.0764
# Validation Accuracy: 0.9108
# TP: 1463, FP: 134, TN: 1488, FN: 155
# Epoch [58/100], Loss: 0.0658
# Validation Accuracy: 0.9059
# TP: 1465, FP: 152, TN: 1470, FN: 153
# Epoch [59/100], Loss: 0.0611
# Validation Accuracy: 0.9105
# TP: 1485, FP: 157, TN: 1465, FN: 133
# Epoch [60/100], Loss: 0.0637
# Validation Accuracy: 0.9059
# TP: 1490, FP: 177, TN: 1445, FN: 128
# Epoch [61/100], Loss: 0.0622
# Validation Accuracy: 0.9080
# TP: 1487, FP: 167, TN: 1455, FN: 131
# Epoch [62/100], Loss: 0.0577
# Validation Accuracy: 0.9025
# TP: 1452, FP: 150, TN: 1472, FN: 166
# Epoch [63/100], Loss: 0.0599
# Validation Accuracy: 0.9105
# TP: 1461, FP: 133, TN: 1489, FN: 157
# Epoch [64/100], Loss: 0.0710
# Validation Accuracy: 0.9108
# TP: 1441, FP: 112, TN: 1510, FN: 177
# Epoch [65/100], Loss: 0.0567
# Validation Accuracy: 0.9046
# TP: 1389, FP: 80, TN: 1542, FN: 229
# Epoch [66/100], Loss: 0.0583
# Validation Accuracy: 0.9077
# TP: 1518, FP: 199, TN: 1423, FN: 100
# Epoch [67/100], Loss: 0.0675
# Validation Accuracy: 0.9093
# TP: 1490, FP: 166, TN: 1456, FN: 128
# Epoch [68/100], Loss: 0.0599
# Validation Accuracy: 0.9056
# TP: 1446, FP: 134, TN: 1488, FN: 172
# Epoch [69/100], Loss: 0.0606
# Validation Accuracy: 0.9136
# TP: 1465, FP: 127, TN: 1495, FN: 153
# Epoch [70/100], Loss: 0.0470
# Validation Accuracy: 0.9108
# TP: 1484, FP: 155, TN: 1467, FN: 134
# Epoch [71/100], Loss: 0.0533
# Validation Accuracy: 0.8920
# TP: 1527, FP: 259, TN: 1363, FN: 91
# Epoch [72/100], Loss: 0.0503
# Validation Accuracy: 0.9031
# TP: 1453, FP: 149, TN: 1473, FN: 165
# Epoch [73/100], Loss: 0.0561
# Validation Accuracy: 0.9031
# TP: 1435, FP: 131, TN: 1491, FN: 183
# Epoch [74/100], Loss: 0.0527
# Validation Accuracy: 0.9111
# TP: 1472, FP: 142, TN: 1480, FN: 146
# Epoch [75/100], Loss: 0.0373
# Validation Accuracy: 0.9034
# TP: 1444, FP: 139, TN: 1483, FN: 174
# Epoch [76/100], Loss: 0.0622
# Validation Accuracy: 0.9105
# TP: 1437, FP: 109, TN: 1513, FN: 181
# Epoch [77/100], Loss: 0.0536
# Validation Accuracy: 0.9090
# TP: 1446, FP: 123, TN: 1499, FN: 172
# Epoch [78/100], Loss: 0.0643
# Validation Accuracy: 0.9111
# TP: 1489, FP: 159, TN: 1463, FN: 129
# Epoch [79/100], Loss: 0.0366
# Validation Accuracy: 0.9090
# TP: 1482, FP: 159, TN: 1463, FN: 136
# Epoch [80/100], Loss: 0.0423
# Validation Accuracy: 0.9065
# TP: 1450, FP: 135, TN: 1487, FN: 168
# Epoch [81/100], Loss: 0.0499
# Validation Accuracy: 0.9108
# TP: 1497, FP: 168, TN: 1454, FN: 121
# Epoch [82/100], Loss: 0.0386
# Validation Accuracy: 0.8972
# TP: 1357, FP: 72, TN: 1550, FN: 261
# Epoch [83/100], Loss: 0.0398
# Validation Accuracy: 0.9099
# TP: 1425, FP: 99, TN: 1523, FN: 193
# Epoch [84/100], Loss: 0.0507
# Validation Accuracy: 0.9114
# TP: 1472, FP: 141, TN: 1481, FN: 146
# Epoch [85/100], Loss: 0.0328
# Validation Accuracy: 0.9114
# TP: 1455, FP: 124, TN: 1498, FN: 163
# Epoch [86/100], Loss: 0.0427
# Validation Accuracy: 0.8981
# TP: 1535, FP: 247, TN: 1375, FN: 83
# Epoch [87/100], Loss: 0.0358
# Validation Accuracy: 0.8877
# TP: 1324, FP: 70, TN: 1552, FN: 294
# Epoch [88/100], Loss: 0.0442
# Validation Accuracy: 0.9037
# TP: 1482, FP: 176, TN: 1446, FN: 136
# Epoch [89/100], Loss: 0.0375
# Validation Accuracy: 0.9077
# TP: 1460, FP: 141, TN: 1481, FN: 158
# Epoch [90/100], Loss: 0.0301
# Validation Accuracy: 0.9080
# TP: 1501, FP: 181, TN: 1441, FN: 117
# Epoch [91/100], Loss: 0.0329
# Validation Accuracy: 0.9093
# TP: 1475, FP: 151, TN: 1471, FN: 143
# Epoch [92/100], Loss: 0.0613
# Validation Accuracy: 0.8914
# TP: 1557, FP: 291, TN: 1331, FN: 61
# Epoch [93/100], Loss: 0.0539
# Validation Accuracy: 0.9025
# TP: 1399, FP: 97, TN: 1525, FN: 219
# Epoch [94/100], Loss: 0.0423
# Validation Accuracy: 0.9083
# TP: 1474, FP: 153, TN: 1469, FN: 144
# Epoch [95/100], Loss: 0.0354
# Validation Accuracy: 0.9083
# TP: 1429, FP: 108, TN: 1514, FN: 189
# Epoch [96/100], Loss: 0.0409
# Validation Accuracy: 0.9074
# TP: 1450, FP: 132, TN: 1490, FN: 168
# Epoch [97/100], Loss: 0.0333
# Validation Accuracy: 0.9068
# TP: 1419, FP: 103, TN: 1519, FN: 199
# Epoch [98/100], Loss: 0.0414
# Validation Accuracy: 0.8917
# TP: 1509, FP: 242, TN: 1380, FN: 109
# Epoch [99/100], Loss: 0.0477
# Validation Accuracy: 0.9019
# TP: 1386, FP: 86, TN: 1536, FN: 232
# Epoch [100/100], Loss: 0.0282
# Validation Accuracy: 0.9105
# TP: 1454, FP: 126, TN: 1496, FN: 164

# %%
print(f"Maximum Validation Accuracy:  {max_val_accuracy:.3f}")
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.3f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.3f}')
print(f'False Positive Rate (FPR): {FPR:.3f}')
# Out:
# Maximum Validation Accuracy:  0.917
# TP:  1457
# FP:  108
# TN:  1514
# FN:  161
# Matthews Correlation Coefficient (MCC): 0.834
# True Positive Rate (TPR): 0.900
# False Positive Rate (FPR): 0.067

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/GPT/opt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)

# %%
Human_embeddings = Human['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/GPT/embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, Human_embeddings)
