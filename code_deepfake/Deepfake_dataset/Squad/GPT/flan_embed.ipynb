# %%
import math
import numpy as np
import os
import pandas as pd
import pickle
from PIL import Image
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer, GPT2Model, pipeline, AutoModelForCausalLM, \
AutoTokenizer, BitsAndBytesConfig, LlamaTokenizer, LlamaModel, AutoModelForTextEncoding
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2') 

from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'flan' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'flan' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'flan' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 3885
# 3885 3885
# 486 486
# 486 486

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
tokenizer.add_special_tokens({'pad_token': '[PAD]'}) 
def generate_bert_embeddings(text):
    input_ids = tokenizer.encode(text, return_tensors='pt',padding=True, truncation=True, max_length=512).to(device) 
    #inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(input_ids)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        #last_hidden_states = outputs.last_hidden_state
        embeddings = outputs.last_hidden_state.mean(dim = 1).squeeze().to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,16,48)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,16,48)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 4857 4857 9714 9714
# /tmp/ipykernel_386274/3934376841.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch

import torch.nn as nn
import torch.optim as optim

class GPT_CNN2D(nn.Module):
    def __init__(self, embedding_model):
        super(GPT_CNN2D, self).__init__()
        self.em_model = embedding_model
        if embedding_model == "gpt":
            self.conv1 = nn.Conv2d(1, 64, kernel_size=5, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(1056, 128)
            self.fc2 = nn.Linear(128, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()
        elif embedding_model == "mistral":
            self.conv1 = nn.Conv2d(1, 128, kernel_size=5, padding=1, stride = 2)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()            
            self.fc1 = nn.Linear(3136, 512)
            self.fc2 = nn.Linear(512, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        if self.em_model == "gpt":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x
        elif self.em_model == "mistral":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GPT_CNN2D(embedding_model = "gpt").to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.7316
# Validation Accuracy: 0.5687
# TP: 918, FP: 783, TN: 187, FN: 55
# Epoch [2/100], Loss: 0.6558
# Validation Accuracy: 0.5775
# TP: 804, FP: 652, TN: 318, FN: 169
# Epoch [3/100], Loss: 0.6329
# Validation Accuracy: 0.6114
# TP: 834, FP: 616, TN: 354, FN: 139
# Epoch [4/100], Loss: 0.5818
# Validation Accuracy: 0.7571
# TP: 660, FP: 159, TN: 811, FN: 313
# Epoch [5/100], Loss: 0.4597
# Validation Accuracy: 0.8369
# TP: 846, FP: 190, TN: 780, FN: 127
# Epoch [6/100], Loss: 0.3577
# Validation Accuracy: 0.8744
# TP: 846, FP: 117, TN: 853, FN: 127
# Epoch [7/100], Loss: 0.2991
# Validation Accuracy: 0.8554
# TP: 917, FP: 225, TN: 745, FN: 56
# Epoch [8/100], Loss: 0.2544
# Validation Accuracy: 0.8873
# TP: 910, FP: 156, TN: 814, FN: 63
# Epoch [9/100], Loss: 0.2278
# Validation Accuracy: 0.9177
# TP: 892, FP: 79, TN: 891, FN: 81
# Epoch [10/100], Loss: 0.2091
# Validation Accuracy: 0.9130
# TP: 857, FP: 53, TN: 917, FN: 116
# Epoch [11/100], Loss: 0.1861
# TP: 886, FP: 34, TN: 936, FN: 87
# Epoch [35/100], Loss: 0.0507
# Validation Accuracy: 0.9352
# TP: 889, FP: 42, TN: 928, FN: 84
# Epoch [36/100], Loss: 0.0371
# Validation Accuracy: 0.9321
# TP: 873, FP: 32, TN: 938, FN: 100
# Epoch [37/100], Loss: 0.0143
# Validation Accuracy: 0.9367
# TP: 925, FP: 75, TN: 895, FN: 48
# Epoch [38/100], Loss: 0.0098
# Validation Accuracy: 0.9388
# TP: 888, FP: 34, TN: 936, FN: 85
# Epoch [39/100], Loss: 0.0068
# Validation Accuracy: 0.9377
# TP: 895, FP: 43, TN: 927, FN: 78
# Epoch [40/100], Loss: 0.0041
# Validation Accuracy: 0.9393
# TP: 893, FP: 38, TN: 932, FN: 80
# Epoch [41/100], Loss: 0.0030
# Validation Accuracy: 0.9398
# TP: 905, FP: 49, TN: 921, FN: 68
# Epoch [42/100], Loss: 0.0026
# Validation Accuracy: 0.9382
# TP: 889, FP: 36, TN: 934, FN: 84
# Epoch [43/100], Loss: 0.0031
# Validation Accuracy: 0.9408
# TP: 909, FP: 51, TN: 919, FN: 64
# Epoch [44/100], Loss: 0.0021
# Validation Accuracy: 0.9377
# TP: 915, FP: 63, TN: 907, FN: 58
# Epoch [45/100], Loss: 0.0032
# Validation Accuracy: 0.9408
# TP: 906, FP: 48, TN: 922, FN: 67
# Epoch [46/100], Loss: 0.0015
# Validation Accuracy: 0.9398
# TP: 897, FP: 41, TN: 929, FN: 76
# Epoch [47/100], Loss: 0.0014
# Validation Accuracy: 0.9408
# TP: 909, FP: 51, TN: 919, FN: 64
# Epoch [48/100], Loss: 0.0011
# Validation Accuracy: 0.9398
# TP: 907, FP: 51, TN: 919, FN: 66
# Epoch [49/100], Loss: 0.0011
# Validation Accuracy: 0.9398
# TP: 909, FP: 53, TN: 917, FN: 64
# Epoch [50/100], Loss: 0.0010
# Validation Accuracy: 0.9388
# TP: 899, FP: 45, TN: 925, FN: 74
# Epoch [51/100], Loss: 0.0009
# Validation Accuracy: 0.9403
# TP: 904, FP: 47, TN: 923, FN: 69
# Epoch [52/100], Loss: 0.0008
# Validation Accuracy: 0.9388
# TP: 901, FP: 47, TN: 923, FN: 72
# Epoch [53/100], Loss: 0.0007
# Validation Accuracy: 0.9393
# TP: 901, FP: 46, TN: 924, FN: 72
# Epoch [54/100], Loss: 0.0007
# Validation Accuracy: 0.9398
# TP: 905, FP: 49, TN: 921, FN: 68
# Epoch [55/100], Loss: 0.0006
# Validation Accuracy: 0.9408
# TP: 894, FP: 36, TN: 934, FN: 79
# Epoch [56/100], Loss: 0.0006
# Validation Accuracy: 0.9413
# TP: 893, FP: 34, TN: 936, FN: 80
# Epoch [57/100], Loss: 0.0005
# Validation Accuracy: 0.9403
# TP: 903, FP: 46, TN: 924, FN: 70
# Epoch [58/100], Loss: 0.0005
# Validation Accuracy: 0.9398
# TP: 896, FP: 40, TN: 930, FN: 77
# Epoch [59/100], Loss: 0.0004
# Validation Accuracy: 0.9398
# TP: 894, FP: 38, TN: 932, FN: 79
# Epoch [60/100], Loss: 0.0004
# Validation Accuracy: 0.9413
# TP: 908, FP: 49, TN: 921, FN: 65
# Epoch [61/100], Loss: 0.0004
# Validation Accuracy: 0.9403
# TP: 903, FP: 46, TN: 924, FN: 70
# Epoch [62/100], Loss: 0.0004
# Validation Accuracy: 0.9418
# TP: 913, FP: 53, TN: 917, FN: 60
# Epoch [63/100], Loss: 0.0003
# Validation Accuracy: 0.9413
# TP: 908, FP: 49, TN: 921, FN: 65
# Epoch [64/100], Loss: 0.0003
# Validation Accuracy: 0.9393
# TP: 904, FP: 49, TN: 921, FN: 69
# Epoch [65/100], Loss: 0.0003
# Validation Accuracy: 0.9403
# TP: 904, FP: 47, TN: 923, FN: 69
# Epoch [66/100], Loss: 0.0003
# Validation Accuracy: 0.9413
# TP: 902, FP: 43, TN: 927, FN: 71
# Epoch [67/100], Loss: 0.0002
# Validation Accuracy: 0.9434
# TP: 904, FP: 41, TN: 929, FN: 69
# Epoch [68/100], Loss: 0.0002
# Validation Accuracy: 0.9403
# TP: 909, FP: 52, TN: 918, FN: 64
# Epoch [69/100], Loss: 0.0002
# Validation Accuracy: 0.9398
# TP: 897, FP: 41, TN: 929, FN: 76
# Epoch [70/100], Loss: 0.0002
# Validation Accuracy: 0.9398
# TP: 904, FP: 48, TN: 922, FN: 69
# Epoch [71/100], Loss: 0.0002
# Validation Accuracy: 0.9398
# TP: 904, FP: 48, TN: 922, FN: 69
# Epoch [72/100], Loss: 0.0002
# Validation Accuracy: 0.9403
# TP: 898, FP: 41, TN: 929, FN: 75
# Epoch [73/100], Loss: 0.0002
# Validation Accuracy: 0.9403
# TP: 899, FP: 42, TN: 928, FN: 74
# Epoch [74/100], Loss: 0.1360
# Validation Accuracy: 0.7663
# TP: 642, FP: 123, TN: 847, FN: 331
# Epoch [75/100], Loss: 0.2444
# Validation Accuracy: 0.8811
# TP: 916, FP: 174, TN: 796, FN: 57
# Epoch [76/100], Loss: 0.1322
# Validation Accuracy: 0.9192
# TP: 864, FP: 48, TN: 922, FN: 109
# Epoch [77/100], Loss: 0.1040
# Validation Accuracy: 0.9038
# TP: 814, FP: 28, TN: 942, FN: 159
# Epoch [78/100], Loss: 0.0836
# Validation Accuracy: 0.9141
# TP: 849, FP: 43, TN: 927, FN: 124
# Epoch [79/100], Loss: 0.0665
# Validation Accuracy: 0.9259
# TP: 883, FP: 54, TN: 916, FN: 90
# Epoch [80/100], Loss: 0.0562
# Validation Accuracy: 0.9202
# TP: 894, FP: 76, TN: 894, FN: 79
# Epoch [81/100], Loss: 0.0494
# Validation Accuracy: 0.9141
# TP: 909, FP: 103, TN: 867, FN: 64
# Epoch [82/100], Loss: 0.0424
# Validation Accuracy: 0.9243
# TP: 867, FP: 41, TN: 929, FN: 106
# Epoch [83/100], Loss: 0.0324
# Validation Accuracy: 0.9207
# TP: 849, FP: 30, TN: 940, FN: 124
# Epoch [84/100], Loss: 0.0285
# Validation Accuracy: 0.9331
# TP: 890, FP: 47, TN: 923, FN: 83
# Epoch [85/100], Loss: 0.0177
# Validation Accuracy: 0.9223
# TP: 915, FP: 93, TN: 877, FN: 58
# Epoch [86/100], Loss: 0.0211
# Validation Accuracy: 0.9259
# TP: 913, FP: 84, TN: 886, FN: 60
# Epoch [87/100], Loss: 0.0210
# Validation Accuracy: 0.9197
# TP: 910, FP: 93, TN: 877, FN: 63
# Epoch [88/100], Loss: 0.0411
# Validation Accuracy: 0.9259
# TP: 921, FP: 92, TN: 878, FN: 52
# Epoch [89/100], Loss: 0.0320
# Validation Accuracy: 0.9259
# TP: 866, FP: 37, TN: 933, FN: 107
# Epoch [90/100], Loss: 0.0189
# Validation Accuracy: 0.9331
# TP: 891, FP: 48, TN: 922, FN: 82
# Epoch [91/100], Loss: 0.0073
# Validation Accuracy: 0.9279
# TP: 873, FP: 40, TN: 930, FN: 100
# Epoch [92/100], Loss: 0.0067
# Validation Accuracy: 0.9352
# TP: 893, FP: 46, TN: 924, FN: 80
# Epoch [93/100], Loss: 0.0037
# Validation Accuracy: 0.9362
# TP: 907, FP: 58, TN: 912, FN: 66
# Epoch [94/100], Loss: 0.0027
# Validation Accuracy: 0.9352
# TP: 896, FP: 49, TN: 921, FN: 77
# Epoch [95/100], Loss: 0.0026
# Validation Accuracy: 0.9372
# TP: 892, FP: 41, TN: 929, FN: 81
# Epoch [96/100], Loss: 0.0019
# Validation Accuracy: 0.9346
# TP: 888, FP: 42, TN: 928, FN: 85
# Epoch [97/100], Loss: 0.0017
# Validation Accuracy: 0.9367
# TP: 904, FP: 54, TN: 916, FN: 69
# Epoch [98/100], Loss: 0.0014
# Validation Accuracy: 0.9352
# TP: 892, FP: 45, TN: 925, FN: 81
# Epoch [99/100], Loss: 0.0013
# Validation Accuracy: 0.9377
# TP: 901, FP: 49, TN: 921, FN: 72
# Epoch [100/100], Loss: 0.0011
# Validation Accuracy: 0.9377
# TP: 903, FP: 51, TN: 919, FN: 70

# %%
print(f"Maximum Validation Accuracy:  {max_val_accuracy:.3f}")
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.3f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.3f}')
print(f'False Positive Rate (FPR): {FPR:.3f}')
# Out:
# Maximum Validation Accuracy:  0.943
# TP:  904
# FP:  41
# TN:  929
# FN:  69
# Matthews Correlation Coefficient (MCC): 0.887
# True Positive Rate (TPR): 0.929
# False Positive Rate (FPR): 0.042

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/GPT/flan_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
