# %%
import math
import numpy as np
import os
import pandas as pd
import pickle
from PIL import Image
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer, GPT2Model, pipeline, AutoModelForCausalLM, \
AutoTokenizer, BitsAndBytesConfig, LlamaTokenizer, LlamaModel, AutoModelForTextEncoding
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2') 

from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")

# %%
llama_sources = ["squad_machine_continuation_7B",
"squad_machine_continuation_65B","squad_machine_continuation_30B","squad_machine_continuation_13B"]

human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']


llm_train = [data for data in dataset['train'] if any(l in data['src'] and 'squad' in data['src'] for l in llama_sources)]
llm_test = [data for data in dataset['test'] if any(l in data['src'] and 'squad' in data['src'] for l in llama_sources)]
llm_val = [data for data in dataset['validation'] if any(l in data['src'] and 'squad' in data['src'] for l in llama_sources)]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 3102
# 3102 3102
# 389 389
# 386 386

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
tokenizer.add_special_tokens({'pad_token': '[PAD]'}) 
def generate_gpt_embeddings(text):
    input_ids = tokenizer.encode(text, return_tensors='pt',padding=True, truncation=True, max_length=512).to(device) 
    #inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(input_ids)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        #last_hidden_states = outputs.last_hidden_state
        embeddings = outputs.last_hidden_state.mean(dim = 1).squeeze().to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_gpt_embeddings)
Human['embeddings'] = Human['text'].apply(generate_gpt_embeddings)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,16,48)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,16,48)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 3877 3877 7754 7754
# /tmp/ipykernel_389451/3934376841.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch

import torch.nn as nn
import torch.optim as optim

class GPT_CNN2D(nn.Module):
    def __init__(self, embedding_model):
        super(GPT_CNN2D, self).__init__()
        self.em_model = embedding_model
        if embedding_model == "gpt":
            self.conv1 = nn.Conv2d(1, 64, kernel_size=5, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(1056, 128)
            self.fc2 = nn.Linear(128, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()
        elif embedding_model == "mistral":
            self.conv1 = nn.Conv2d(1, 128, kernel_size=5, padding=1, stride = 2)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()            
            self.fc1 = nn.Linear(3136, 512)
            self.fc2 = nn.Linear(512, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        if self.em_model == "gpt":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x
        elif self.em_model == "mistral":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GPT_CNN2D(embedding_model = "gpt").to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.7159
# Validation Accuracy: 0.5119
# TP: 20, FP: 7, TN: 774, FN: 750
# Epoch [2/100], Loss: 0.6304
# Validation Accuracy: 0.6834
# TP: 586, FP: 307, TN: 474, FN: 184
# Epoch [3/100], Loss: 0.5593
# Validation Accuracy: 0.7260
# TP: 496, FP: 151, TN: 630, FN: 274
# Epoch [4/100], Loss: 0.5026
# Validation Accuracy: 0.7776
# TP: 603, FP: 178, TN: 603, FN: 167
# Epoch [5/100], Loss: 0.4421
# Validation Accuracy: 0.8027
# TP: 692, FP: 228, TN: 553, FN: 78
# Epoch [6/100], Loss: 0.3718
# Validation Accuracy: 0.8375
# TP: 735, FP: 217, TN: 564, FN: 35
# Epoch [7/100], Loss: 0.3155
# Validation Accuracy: 0.8472
# TP: 751, FP: 218, TN: 563, FN: 19
# Epoch [8/100], Loss: 0.2778
# Validation Accuracy: 0.8923
# TP: 733, FP: 130, TN: 651, FN: 37
# Epoch [9/100], Loss: 0.2584
# Validation Accuracy: 0.9001
# TP: 695, FP: 80, TN: 701, FN: 75
# Epoch [10/100], Loss: 0.2242
# Validation Accuracy: 0.9033
# TP: 661, FP: 41, TN: 740, FN: 109
# Epoch [11/100], Loss: 0.2005
# Validation Accuracy: 0.9155
# TP: 704, FP: 65, TN: 716, FN: 66
# Epoch [12/100], Loss: 0.1942
# Validation Accuracy: 0.9020
# TP: 749, FP: 131, TN: 650, FN: 21
# Epoch [13/100], Loss: 0.1739
# Validation Accuracy: 0.9175
# TP: 711, FP: 69, TN: 712, FN: 59
# Epoch [14/100], Loss: 0.1654
# Validation Accuracy: 0.9155
# TP: 738, FP: 99, TN: 682, FN: 32
# Epoch [15/100], Loss: 0.1517
# Validation Accuracy: 0.9136
# TP: 690, FP: 54, TN: 727, FN: 80
# Epoch [16/100], Loss: 0.1352
# Validation Accuracy: 0.9207
# TP: 733, FP: 86, TN: 695, FN: 37
# Epoch [17/100], Loss: 0.1219
# Validation Accuracy: 0.9239
# TP: 722, FP: 70, TN: 711, FN: 48
# Epoch [18/100], Loss: 0.1156
# Validation Accuracy: 0.9233
# TP: 738, FP: 87, TN: 694, FN: 32
# Epoch [19/100], Loss: 0.1202
# Validation Accuracy: 0.9265
# TP: 717, FP: 61, TN: 720, FN: 53
# Epoch [20/100], Loss: 0.1073
# Validation Accuracy: 0.9175
# TP: 676, FP: 34, TN: 747, FN: 94
# Epoch [21/100], Loss: 0.1327
# Validation Accuracy: 0.9213
# TP: 721, FP: 73, TN: 708, FN: 49
# Epoch [22/100], Loss: 0.1017
# Validation Accuracy: 0.9271
# TP: 722, FP: 65, TN: 716, FN: 48
# Epoch [23/100], Loss: 0.0841
# Validation Accuracy: 0.9059
# TP: 751, FP: 127, TN: 654, FN: 19
# Epoch [24/100], Loss: 0.1099
# Validation Accuracy: 0.9130
# TP: 712, FP: 77, TN: 704, FN: 58
# Epoch [25/100], Loss: 0.0864
# Validation Accuracy: 0.9220
# TP: 698, FP: 49, TN: 732, FN: 72
# Epoch [26/100], Loss: 0.0681
# Validation Accuracy: 0.9271
# TP: 741, FP: 84, TN: 697, FN: 29
# Epoch [27/100], Loss: 0.0626
# Validation Accuracy: 0.9149
# TP: 672, FP: 34, TN: 747, FN: 98
# Epoch [28/100], Loss: 0.0603
# Validation Accuracy: 0.9181
# TP: 744, FP: 101, TN: 680, FN: 26
# Epoch [29/100], Loss: 0.0598
# Validation Accuracy: 0.9310
# TP: 731, FP: 68, TN: 713, FN: 39
# Epoch [30/100], Loss: 0.0537
# Validation Accuracy: 0.9284
# TP: 737, FP: 78, TN: 703, FN: 33
# Epoch [31/100], Loss: 0.0483
# Validation Accuracy: 0.8833
# TP: 759, FP: 170, TN: 611, FN: 11
# Epoch [32/100], Loss: 0.0523
# Validation Accuracy: 0.9271
# TP: 702, FP: 45, TN: 736, FN: 68
# Epoch [33/100], Loss: 0.0444
# Validation Accuracy: 0.8859
# TP: 754, FP: 161, TN: 620, FN: 16
# Epoch [34/100], Loss: 0.0630
# Validation Accuracy: 0.9091
# TP: 668, FP: 39, TN: 742, FN: 102
# Epoch [35/100], Loss: 0.0486
# Validation Accuracy: 0.9207
# TP: 732, FP: 85, TN: 696, FN: 38
# Epoch [36/100], Loss: 0.0385
# Validation Accuracy: 0.8981
# TP: 637, FP: 25, TN: 756, FN: 133
# Epoch [37/100], Loss: 0.0463
# Validation Accuracy: 0.9271
# TP: 711, FP: 54, TN: 727, FN: 59
# Epoch [38/100], Loss: 0.0371
# Validation Accuracy: 0.9310
# TP: 706, FP: 43, TN: 738, FN: 64
# Epoch [39/100], Loss: 0.0200
# Validation Accuracy: 0.9252
# TP: 691, FP: 37, TN: 744, FN: 79
# Epoch [40/100], Loss: 0.0186
# Validation Accuracy: 0.9239
# TP: 690, FP: 38, TN: 743, FN: 80
# Epoch [41/100], Loss: 0.0315
# Validation Accuracy: 0.9291
# TP: 722, FP: 62, TN: 719, FN: 48
# Epoch [42/100], Loss: 0.0243
# Validation Accuracy: 0.9084
# TP: 659, FP: 31, TN: 750, FN: 111
# Epoch [43/100], Loss: 0.0206
# Validation Accuracy: 0.9097
# TP: 651, FP: 21, TN: 760, FN: 119
# Epoch [44/100], Loss: 0.0177
# Validation Accuracy: 0.9271
# TP: 696, FP: 39, TN: 742, FN: 74
# Epoch [45/100], Loss: 0.0395
# Validation Accuracy: 0.9194
# TP: 702, FP: 57, TN: 724, FN: 68
# Epoch [46/100], Loss: 0.0445
# Validation Accuracy: 0.9175
# TP: 675, FP: 33, TN: 748, FN: 95
# Epoch [47/100], Loss: 0.0317
# Validation Accuracy: 0.9213
# TP: 702, FP: 54, TN: 727, FN: 68
# Epoch [48/100], Loss: 0.0139
# Validation Accuracy: 0.9291
# TP: 735, FP: 75, TN: 706, FN: 35
# Epoch [49/100], Loss: 0.0131
# Validation Accuracy: 0.9297
# TP: 704, FP: 43, TN: 738, FN: 66
# Epoch [50/100], Loss: 0.0083
# Validation Accuracy: 0.9323
# TP: 698, FP: 33, TN: 748, FN: 72
# Epoch [51/100], Loss: 0.0101
# Validation Accuracy: 0.9323
# TP: 709, FP: 44, TN: 737, FN: 61
# Epoch [52/100], Loss: 0.0048
# Validation Accuracy: 0.9149
# TP: 672, FP: 34, TN: 747, FN: 98
# Epoch [53/100], Loss: 0.0106
# Validation Accuracy: 0.9336
# TP: 707, FP: 40, TN: 741, FN: 63
# Epoch [54/100], Loss: 0.0092
# Validation Accuracy: 0.9239
# TP: 696, FP: 44, TN: 737, FN: 74
# Epoch [55/100], Loss: 0.0107
# Validation Accuracy: 0.9329
# TP: 711, FP: 45, TN: 736, FN: 59
# Epoch [56/100], Loss: 0.0040
# Validation Accuracy: 0.9310
# TP: 715, FP: 52, TN: 729, FN: 55
# Epoch [57/100], Loss: 0.0056
# Validation Accuracy: 0.9336
# TP: 715, FP: 48, TN: 733, FN: 55
# Epoch [58/100], Loss: 0.0620
# Validation Accuracy: 0.9117
# TP: 730, FP: 97, TN: 684, FN: 40
# Epoch [59/100], Loss: 0.0490
# Validation Accuracy: 0.9342
# TP: 730, FP: 62, TN: 719, FN: 40
# Epoch [60/100], Loss: 0.0351
# Validation Accuracy: 0.9271
# TP: 707, FP: 50, TN: 731, FN: 63
# Epoch [61/100], Loss: 0.0106
# Validation Accuracy: 0.9355
# TP: 716, FP: 46, TN: 735, FN: 54
# Epoch [62/100], Loss: 0.0074
# Validation Accuracy: 0.9387
# TP: 726, FP: 51, TN: 730, FN: 44
# Epoch [63/100], Loss: 0.0087
# Validation Accuracy: 0.9271
# TP: 708, FP: 51, TN: 730, FN: 62
# Epoch [64/100], Loss: 0.0054
# Validation Accuracy: 0.9284
# TP: 696, FP: 37, TN: 744, FN: 74
# Epoch [65/100], Loss: 0.0098
# Validation Accuracy: 0.9220
# TP: 684, FP: 35, TN: 746, FN: 86
# Epoch [66/100], Loss: 0.0098
# Validation Accuracy: 0.9155
# TP: 670, FP: 31, TN: 750, FN: 100
# Epoch [67/100], Loss: 0.0045
# Validation Accuracy: 0.9375
# TP: 717, FP: 44, TN: 737, FN: 53
# Epoch [68/100], Loss: 0.0045
# Validation Accuracy: 0.9368
# TP: 723, FP: 51, TN: 730, FN: 47
# Epoch [69/100], Loss: 0.0089
# Validation Accuracy: 0.9246
# TP: 692, FP: 39, TN: 742, FN: 78
# Epoch [70/100], Loss: 0.0134
# Validation Accuracy: 0.9323
# TP: 711, FP: 46, TN: 735, FN: 59
# Epoch [71/100], Loss: 0.0737
# Validation Accuracy: 0.9220
# TP: 696, FP: 47, TN: 734, FN: 74
# Epoch [72/100], Loss: 0.0154
# Validation Accuracy: 0.9291
# TP: 708, FP: 48, TN: 733, FN: 62
# Epoch [73/100], Loss: 0.0093
# Validation Accuracy: 0.9291
# TP: 707, FP: 47, TN: 734, FN: 63
# Epoch [74/100], Loss: 0.0060
# Validation Accuracy: 0.9317
# TP: 706, FP: 42, TN: 739, FN: 64
# Epoch [75/100], Loss: 0.0043
# Validation Accuracy: 0.9278
# TP: 724, FP: 66, TN: 715, FN: 46
# Epoch [76/100], Loss: 0.0060
# Validation Accuracy: 0.9362
# TP: 723, FP: 52, TN: 729, FN: 47
# Epoch [77/100], Loss: 0.0053
# Validation Accuracy: 0.9317
# TP: 722, FP: 58, TN: 723, FN: 48
# Epoch [78/100], Loss: 0.0054
# Validation Accuracy: 0.9310
# TP: 717, FP: 54, TN: 727, FN: 53
# Epoch [79/100], Loss: 0.0072
# Validation Accuracy: 0.9265
# TP: 716, FP: 60, TN: 721, FN: 54
# Epoch [80/100], Loss: 0.0292
# Validation Accuracy: 0.9142
# TP: 688, FP: 51, TN: 730, FN: 82
# Epoch [81/100], Loss: 0.0532
# Validation Accuracy: 0.9194
# TP: 685, FP: 40, TN: 741, FN: 85
# Epoch [82/100], Loss: 0.0246
# Validation Accuracy: 0.9284
# TP: 712, FP: 53, TN: 728, FN: 58
# Epoch [83/100], Loss: 0.0056
# Validation Accuracy: 0.9304
# TP: 708, FP: 46, TN: 735, FN: 62
# Epoch [84/100], Loss: 0.0033
# Validation Accuracy: 0.9297
# TP: 723, FP: 62, TN: 719, FN: 47
# Epoch [85/100], Loss: 0.0031
# Validation Accuracy: 0.9297
# TP: 712, FP: 51, TN: 730, FN: 58
# Epoch [86/100], Loss: 0.0031
# Validation Accuracy: 0.9291
# TP: 727, FP: 67, TN: 714, FN: 43
# Epoch [87/100], Loss: 0.0037
# Validation Accuracy: 0.9265
# TP: 730, FP: 74, TN: 707, FN: 40
# Epoch [88/100], Loss: 0.0052
# Validation Accuracy: 0.9304
# TP: 724, FP: 62, TN: 719, FN: 46
# Epoch [89/100], Loss: 0.0054
# Validation Accuracy: 0.9220
# TP: 680, FP: 31, TN: 750, FN: 90
# Epoch [90/100], Loss: 0.0042
# Validation Accuracy: 0.9265
# TP: 723, FP: 67, TN: 714, FN: 47
# Epoch [91/100], Loss: 0.0036
# Validation Accuracy: 0.9252
# TP: 684, FP: 30, TN: 751, FN: 86
# Epoch [92/100], Loss: 0.0647
# Validation Accuracy: 0.8994
# TP: 643, FP: 29, TN: 752, FN: 127
# Epoch [93/100], Loss: 0.0316
# Validation Accuracy: 0.9323
# TP: 720, FP: 55, TN: 726, FN: 50
# Epoch [94/100], Loss: 0.0045
# Validation Accuracy: 0.9297
# TP: 715, FP: 54, TN: 727, FN: 55
# Epoch [95/100], Loss: 0.0029
# Validation Accuracy: 0.9304
# TP: 714, FP: 52, TN: 729, FN: 56
# Epoch [96/100], Loss: 0.0027
# Validation Accuracy: 0.9297
# TP: 711, FP: 50, TN: 731, FN: 59
# Epoch [97/100], Loss: 0.0044
# Validation Accuracy: 0.9317
# TP: 715, FP: 51, TN: 730, FN: 55
# Epoch [98/100], Loss: 0.0036
# Validation Accuracy: 0.9304
# TP: 700, FP: 38, TN: 743, FN: 70
# Epoch [99/100], Loss: 0.0026
# Validation Accuracy: 0.9291
# TP: 715, FP: 55, TN: 726, FN: 55
# Epoch [100/100], Loss: 0.0036
# Validation Accuracy: 0.9323
# TP: 718, FP: 53, TN: 728, FN: 52

# %%
print(f"Maximum Validation Accuracy:  {max_val_accuracy:.3f}")
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.3f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.3f}')
print(f'False Positive Rate (FPR): {FPR:.3f}')
# Out:
# Maximum Validation Accuracy:  0.939
# TP:  726
# FP:  51
# TN:  730
# FN:  44
# Matthews Correlation Coefficient (MCC): 0.878
# True Positive Rate (TPR): 0.943
# False Positive Rate (FPR): 0.065

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/GPT/llama_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
