# %%
import math
import numpy as np
import os
import pandas as pd
import pickle
from PIL import Image
from sklearn.metrics import confusion_matrix, matthews_corrcoef
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from transformers import GPT2Tokenizer, GPT2Model, pipeline, AutoModelForCausalLM, \
AutoTokenizer, BitsAndBytesConfig, LlamaTokenizer, LlamaModel, AutoModelForTextEncoding
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import pandas as pd
from PIL import Image
from tqdm import tqdm
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from transformers import RobertaModel, RobertaTokenizer
import random
seed_value = 42
torch.manual_seed(seed_value)
np.random.seed(seed_value)

random.seed(seed_value)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2') 

from datasets import load_dataset
dataset = load_dataset("yaful/DeepfakeTextDetect")

# %%
human_train = [data for data in dataset['train'] if data['src'] == 'squad_human']
human_test = [data for data in dataset['test'] if data['src'] == 'squad_human']
human_val = [data for data in dataset['validation'] if data['src'] == 'squad_human']

llm_train = [data for data in dataset['train'] if 'gpt' in data['src'] and 'squad' in data['src']]
llm_test = [data for data in dataset['test'] if 'gpt' in data['src'] and 'squad' in data['src']]
llm_val = [data for data in dataset['validation'] if 'gpt' in data['src'] and 'squad' in data['src']]

import random

min_train_length = min(len(human_train), len(llm_train))
min_test_length = min(len(human_test), len(llm_test))
min_val_length = min(len(human_val), len(llm_val))

squad_human_train = random.sample(human_train, min_train_length)
squad_human_test = random.sample(human_test, min_test_length)
squad_human_val = random.sample(human_val, min_val_length)

squad_gpt_train = random.sample(llm_train, min_train_length)
squad_gpt_test = random.sample(llm_train, min_test_length)
squad_gpt_val = random.sample(llm_val, min_val_length)

print(len(human_train), len(llm_train))
print(len(squad_human_train), len(squad_gpt_train))
print(len(squad_human_test), len(squad_gpt_test))
print(len(squad_human_val), len(squad_gpt_val))
# Out:
# 15820 1830
# 1830 1830
# 228 228
# 220 220

# %%
import pandas as pd

Human = pd.DataFrame()
squad_human = squad_human_train + squad_human_val + squad_human_test
Human['text'] = [data['text'] for data in squad_human]

AI = pd.DataFrame()
squad_gpt = squad_gpt_train + squad_gpt_val + squad_gpt_test
AI['text'] = [data['text'] for data in squad_gpt]

# %%
import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to('cuda')
tokenizer.add_special_tokens({'pad_token': '[PAD]'}) 
def generate_bert_embeddings(text):
    input_ids = tokenizer.encode(text, return_tensors='pt',padding=True, truncation=True, max_length=512).to(device) 
    #inputs = {name: tensor.to('cuda') for name, tensor in inputs.items()}  # Move inputs to GPU
    with torch.no_grad():
        outputs = model(input_ids)
        #embeddings = torch.mean(outputs.last_hidden_state, dim=1)  # Mean pooling of token embeddings
        #last_hidden_states = outputs.last_hidden_state
        embeddings = outputs.last_hidden_state.mean(dim = 1).squeeze().to('cpu')
    return embeddings.numpy()
import numpy as np

AI['embeddings'] = AI['text'].apply(generate_bert_embeddings)
Human['embeddings'] = Human['text'].apply(generate_bert_embeddings)

# %%
AI['embeddings'][0].shape
# Out:
# (768,)

# %%
Human_embeddings = Human['embeddings']
AI_embeddings = AI['embeddings']
reshaped_gpt = []
for i in range(len(AI_embeddings)):
    reshaped = AI_embeddings[i].reshape(1,16,48)
    reshaped_gpt.append(reshaped)
    
reshaped_human = []
for i in range(len(Human_embeddings)):
    reshaped = Human_embeddings[i].reshape(1,16,48)
    reshaped_human.append(reshaped)
    
import torch

reshaped_gpt_tensor = torch.tensor(reshaped_gpt)
reshaped_human_tensor = torch.tensor(reshaped_human)

import torch

# Create tensors with zeros and ones
zeros_tensor = torch.zeros(len(reshaped_gpt))
ones_tensor = torch.ones(len(reshaped_human))

# Concatenate the tensors along the first dimension
labels = torch.cat((zeros_tensor, ones_tensor), dim=0)

# Display the result tensor
print(labels)
embeds = torch.cat((reshaped_gpt_tensor, reshaped_human_tensor), dim=0)

print(len(reshaped_gpt_tensor), len(reshaped_human_tensor), len(embeds), len(labels))
# Out:
# tensor([0., 0., 0.,  ..., 1., 1., 1.])
# 2278 2278 4556 4556
# /tmp/ipykernel_381609/3934376841.py:15: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1682343995622/work/torch/csrc/utils/tensor_new.cpp:245.)
#   reshaped_gpt_tensor = torch.tensor(reshaped_gpt)

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

test_size = 0.2
dataset = TensorDataset(embeds, labels)

# Split dataset into train and test sets
train_dataset, test_dataset = train_test_split(dataset, test_size=test_size, random_state=42)

# Define batch size
batch_size = 64

# Create DataLoader for training set
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
import torch

import torch.nn as nn
import torch.optim as optim

class GPT_CNN2D(nn.Module):
    def __init__(self, embedding_model):
        super(GPT_CNN2D, self).__init__()
        self.em_model = embedding_model
        if embedding_model == "gpt":
            self.conv1 = nn.Conv2d(1, 64, kernel_size=5, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(64, 32, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()
            self.fc1 = nn.Linear(1056, 128)
            self.fc2 = nn.Linear(128, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()
        elif embedding_model == "mistral":
            self.conv1 = nn.Conv2d(1, 128, kernel_size=5, padding=1, stride = 2)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.conv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
            self.pool = nn.MaxPool2d(kernel_size=2)
            self.flatten = nn.Flatten()            
            self.fc1 = nn.Linear(3136, 512)
            self.fc2 = nn.Linear(512, 2)
            self.relu = nn.ReLU()
            # self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        if self.em_model == "gpt":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x
        elif self.em_model == "mistral":
            x = self.conv1(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.conv2(x)
            x = self.relu(x)
            x = self.pool(x)
            x = self.flatten(x)
            x = self.relu(self.fc1(x))
            x = self.fc2(x)
            # x = self.sigmoid(self.fc2(x))
            return x

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = GPT_CNN2D(embedding_model = "gpt").to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
max_val_accuracy = 0
# Step 5: Training Loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device).long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.4f}')
    
    # Validation
    model.eval()
    correct = 0
    total = 0
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device).long()
            outputs = model(inputs)
            predicted = torch.argmax(outputs, 1)
            TP += ((predicted == 1) & (labels == 1)).sum().item()
            FP += ((predicted == 1) & (labels == 0)).sum().item()
            TN += ((predicted == 0) & (labels == 0)).sum().item()
            FN += ((predicted == 0) & (labels == 1)).sum().item()
            total += labels.size(0)
            #print(labels, predicted)
            correct += (predicted == labels).sum().item()
    val_accuracy = correct / total
    if max_val_accuracy<val_accuracy:
        max_TP = TP
        max_FP = FP
        max_TN = TN
        max_FN = FN
    max_val_accuracy = max(max_val_accuracy, val_accuracy)
    
    
    print(f'Validation Accuracy: {val_accuracy:.4f}')
    print(f'TP: {TP}, FP: {FP}, TN: {TN}, FN: {FN}')
# Out:
# Epoch [1/100], Loss: 0.7674
# Validation Accuracy: 0.4978
# TP: 427, FP: 446, TN: 27, FN: 12
# Epoch [2/100], Loss: 0.6928
# Validation Accuracy: 0.5197
# TP: 6, FP: 5, TN: 468, FN: 433
# Epoch [3/100], Loss: 0.6898
# Validation Accuracy: 0.5373
# TP: 39, FP: 22, TN: 451, FN: 400
# Epoch [4/100], Loss: 0.6890
# Validation Accuracy: 0.5943
# TP: 263, FP: 194, TN: 279, FN: 176
# Epoch [5/100], Loss: 0.6763
# Validation Accuracy: 0.5482
# TP: 397, FP: 370, TN: 103, FN: 42
# Epoch [6/100], Loss: 0.6564
# Validation Accuracy: 0.5866
# TP: 407, FP: 345, TN: 128, FN: 32
# Epoch [7/100], Loss: 0.6283
# Validation Accuracy: 0.6283
# TP: 411, FP: 311, TN: 162, FN: 28
# Epoch [8/100], Loss: 0.5864
# Validation Accuracy: 0.6634
# TP: 416, FP: 284, TN: 189, FN: 23
# Epoch [9/100], Loss: 0.5455
# Validation Accuracy: 0.7390
# TP: 367, FP: 166, TN: 307, FN: 72
# Epoch [10/100], Loss: 0.4890
# Validation Accuracy: 0.7654
# TP: 371, FP: 146, TN: 327, FN: 68
# Epoch [11/100], Loss: 0.4492
# Validation Accuracy: 0.7785
# TP: 296, FP: 59, TN: 414, FN: 143
# Epoch [12/100], Loss: 0.4231
# Validation Accuracy: 0.8158
# TP: 354, FP: 83, TN: 390, FN: 85
# Epoch [13/100], Loss: 0.4246
# Validation Accuracy: 0.8158
# TP: 365, FP: 94, TN: 379, FN: 74
# Epoch [14/100], Loss: 0.3803
# Validation Accuracy: 0.8213
# TP: 396, FP: 120, TN: 353, FN: 43
# Epoch [15/100], Loss: 0.3517
# Validation Accuracy: 0.8158
# TP: 406, FP: 135, TN: 338, FN: 33
# Epoch [16/100], Loss: 0.3332
# Validation Accuracy: 0.8279
# TP: 409, FP: 127, TN: 346, FN: 30
# Epoch [17/100], Loss: 0.3270
# Validation Accuracy: 0.7851
# TP: 420, FP: 177, TN: 296, FN: 19
# Epoch [18/100], Loss: 0.3158
# Validation Accuracy: 0.8070
# TP: 419, FP: 156, TN: 317, FN: 20
# Epoch [19/100], Loss: 0.2871
# Validation Accuracy: 0.8311
# TP: 314, FP: 29, TN: 444, FN: 125
# Epoch [20/100], Loss: 0.2783
# Validation Accuracy: 0.8564
# TP: 390, FP: 82, TN: 391, FN: 49
# Epoch [21/100], Loss: 0.2719
# Validation Accuracy: 0.8739
# TP: 388, FP: 64, TN: 409, FN: 51
# Epoch [22/100], Loss: 0.2761
# Validation Accuracy: 0.8509
# TP: 396, FP: 93, TN: 380, FN: 43
# Epoch [23/100], Loss: 0.2437
# Validation Accuracy: 0.8695
# TP: 368, FP: 48, TN: 425, FN: 71
# Epoch [24/100], Loss: 0.2291
# Validation Accuracy: 0.8586
# TP: 407, FP: 97, TN: 376, FN: 32
# Epoch [25/100], Loss: 0.2270
# Validation Accuracy: 0.8629
# TP: 402, FP: 88, TN: 385, FN: 37
# Epoch [26/100], Loss: 0.2093
# Validation Accuracy: 0.8695
# TP: 358, FP: 38, TN: 435, FN: 81
# Epoch [27/100], Loss: 0.2070
# Validation Accuracy: 0.8695
# TP: 357, FP: 37, TN: 436, FN: 82
# Epoch [28/100], Loss: 0.1970
# Validation Accuracy: 0.8827
# TP: 372, FP: 40, TN: 433, FN: 67
# Epoch [29/100], Loss: 0.1743
# Validation Accuracy: 0.8750
# TP: 395, FP: 70, TN: 403, FN: 44
# Epoch [30/100], Loss: 0.1707
# Validation Accuracy: 0.8684
# TP: 404, FP: 85, TN: 388, FN: 35
# Epoch [31/100], Loss: 0.1641
# Validation Accuracy: 0.8849
# TP: 374, FP: 40, TN: 433, FN: 65
# Epoch [32/100], Loss: 0.1533
# Validation Accuracy: 0.8849
# TP: 372, FP: 38, TN: 435, FN: 67
# Epoch [33/100], Loss: 0.1357
# Validation Accuracy: 0.8542
# TP: 407, FP: 101, TN: 372, FN: 32
# Epoch [34/100], Loss: 0.1505
# Validation Accuracy: 0.8739
# TP: 409, FP: 85, TN: 388, FN: 30
# Epoch [35/100], Loss: 0.1304
# Validation Accuracy: 0.8553
# TP: 335, FP: 28, TN: 445, FN: 104
# Epoch [36/100], Loss: 0.1206
# Validation Accuracy: 0.8794
# TP: 365, FP: 36, TN: 437, FN: 74
# Epoch [37/100], Loss: 0.1219
# Validation Accuracy: 0.8816
# TP: 399, FP: 68, TN: 405, FN: 40
# Epoch [38/100], Loss: 0.1175
# Validation Accuracy: 0.8805
# TP: 387, FP: 57, TN: 416, FN: 52
# Epoch [39/100], Loss: 0.1133
# Validation Accuracy: 0.8706
# TP: 357, FP: 36, TN: 437, FN: 82
# Epoch [40/100], Loss: 0.0915
# Validation Accuracy: 0.8750
# TP: 405, FP: 80, TN: 393, FN: 34
# Epoch [41/100], Loss: 0.0917
# Validation Accuracy: 0.8684
# TP: 355, FP: 36, TN: 437, FN: 84
# Epoch [42/100], Loss: 0.0902
# Validation Accuracy: 0.8783
# TP: 393, FP: 65, TN: 408, FN: 46
# Epoch [43/100], Loss: 0.0765
# Validation Accuracy: 0.8783
# TP: 401, FP: 73, TN: 400, FN: 38
# Epoch [44/100], Loss: 0.0893
# Validation Accuracy: 0.8739
# TP: 364, FP: 40, TN: 433, FN: 75
# Epoch [45/100], Loss: 0.0706
# Validation Accuracy: 0.8838
# TP: 396, FP: 63, TN: 410, FN: 43
# Epoch [46/100], Loss: 0.0646
# Validation Accuracy: 0.8816
# TP: 396, FP: 65, TN: 408, FN: 43
# Epoch [47/100], Loss: 0.0507
# Validation Accuracy: 0.8662
# TP: 405, FP: 88, TN: 385, FN: 34
# Epoch [48/100], Loss: 0.0459
# Validation Accuracy: 0.8684
# TP: 400, FP: 81, TN: 392, FN: 39
# Epoch [49/100], Loss: 0.0555
# Validation Accuracy: 0.8805
# TP: 380, FP: 50, TN: 423, FN: 59
# Epoch [50/100], Loss: 0.0453
# Validation Accuracy: 0.8794
# TP: 388, FP: 59, TN: 414, FN: 51
# Epoch [51/100], Loss: 0.0362
# Validation Accuracy: 0.8838
# TP: 389, FP: 56, TN: 417, FN: 50
# Epoch [52/100], Loss: 0.0363
# Validation Accuracy: 0.8827
# TP: 386, FP: 54, TN: 419, FN: 53
# Epoch [53/100], Loss: 0.0309
# Validation Accuracy: 0.8882
# TP: 381, FP: 44, TN: 429, FN: 58
# Epoch [54/100], Loss: 0.0253
# Validation Accuracy: 0.8717
# TP: 356, FP: 34, TN: 439, FN: 83
# Epoch [55/100], Loss: 0.0527
# Validation Accuracy: 0.8684
# TP: 393, FP: 74, TN: 399, FN: 46
# Epoch [56/100], Loss: 0.0662
# Validation Accuracy: 0.8607
# TP: 338, FP: 26, TN: 447, FN: 101
# Epoch [57/100], Loss: 0.0563
# Validation Accuracy: 0.8838
# TP: 378, FP: 45, TN: 428, FN: 61
# Epoch [58/100], Loss: 0.0396
# Validation Accuracy: 0.8717
# TP: 388, FP: 66, TN: 407, FN: 51
# Epoch [59/100], Loss: 0.0646
# Validation Accuracy: 0.8783
# TP: 392, FP: 64, TN: 409, FN: 47
# Epoch [60/100], Loss: 0.0392
# Validation Accuracy: 0.8706
# TP: 363, FP: 42, TN: 431, FN: 76
# Epoch [61/100], Loss: 0.0190
# Validation Accuracy: 0.8871
# TP: 393, FP: 57, TN: 416, FN: 46
# Epoch [62/100], Loss: 0.0127
# Validation Accuracy: 0.8794
# TP: 370, FP: 41, TN: 432, FN: 69
# Epoch [63/100], Loss: 0.0114
# Validation Accuracy: 0.8827
# TP: 382, FP: 50, TN: 423, FN: 57
# Epoch [64/100], Loss: 0.0091
# Validation Accuracy: 0.8772
# TP: 388, FP: 61, TN: 412, FN: 51
# Epoch [65/100], Loss: 0.0074
# Validation Accuracy: 0.8816
# TP: 373, FP: 42, TN: 431, FN: 66
# Epoch [66/100], Loss: 0.0070
# Validation Accuracy: 0.8805
# TP: 379, FP: 49, TN: 424, FN: 60
# Epoch [67/100], Loss: 0.0094
# Validation Accuracy: 0.8783
# TP: 381, FP: 53, TN: 420, FN: 58
# Epoch [68/100], Loss: 0.0061
# Validation Accuracy: 0.8772
# TP: 381, FP: 54, TN: 419, FN: 58
# Epoch [69/100], Loss: 0.0056
# Validation Accuracy: 0.8783
# TP: 378, FP: 50, TN: 423, FN: 61
# Epoch [70/100], Loss: 0.0051
# Validation Accuracy: 0.8849
# TP: 384, FP: 50, TN: 423, FN: 55
# Epoch [71/100], Loss: 0.0052
# Validation Accuracy: 0.8805
# TP: 380, FP: 50, TN: 423, FN: 59
# Epoch [72/100], Loss: 0.0046
# Validation Accuracy: 0.8750
# TP: 381, FP: 56, TN: 417, FN: 58
# Epoch [73/100], Loss: 0.0043
# Validation Accuracy: 0.8816
# TP: 379, FP: 48, TN: 425, FN: 60
# Epoch [74/100], Loss: 0.0034
# Validation Accuracy: 0.8783
# TP: 384, FP: 56, TN: 417, FN: 55
# Epoch [75/100], Loss: 0.0032
# Validation Accuracy: 0.8816
# TP: 384, FP: 53, TN: 420, FN: 55
# Epoch [76/100], Loss: 0.0029
# Validation Accuracy: 0.8816
# TP: 382, FP: 51, TN: 422, FN: 57
# Epoch [77/100], Loss: 0.0027
# Validation Accuracy: 0.8805
# TP: 380, FP: 50, TN: 423, FN: 59
# Epoch [78/100], Loss: 0.0026
# Validation Accuracy: 0.8816
# TP: 381, FP: 50, TN: 423, FN: 58
# Epoch [79/100], Loss: 0.0026
# Validation Accuracy: 0.8783
# TP: 381, FP: 53, TN: 420, FN: 58
# Epoch [80/100], Loss: 0.0023
# Validation Accuracy: 0.8739
# TP: 380, FP: 56, TN: 417, FN: 59
# Epoch [81/100], Loss: 0.0023
# Validation Accuracy: 0.8717
# TP: 388, FP: 66, TN: 407, FN: 51
# Epoch [82/100], Loss: 0.0021
# Validation Accuracy: 0.8827
# TP: 383, FP: 51, TN: 422, FN: 56
# Epoch [83/100], Loss: 0.0020
# Validation Accuracy: 0.8816
# TP: 378, FP: 47, TN: 426, FN: 61
# Epoch [84/100], Loss: 0.0021
# Validation Accuracy: 0.8827
# TP: 379, FP: 47, TN: 426, FN: 60
# Epoch [85/100], Loss: 0.0018
# Validation Accuracy: 0.8772
# TP: 383, FP: 56, TN: 417, FN: 56
# Epoch [86/100], Loss: 0.0016
# Validation Accuracy: 0.8805
# TP: 380, FP: 50, TN: 423, FN: 59
# Epoch [87/100], Loss: 0.0015
# Validation Accuracy: 0.8827
# TP: 385, FP: 53, TN: 420, FN: 54
# Epoch [88/100], Loss: 0.0014
# Validation Accuracy: 0.8816
# TP: 385, FP: 54, TN: 419, FN: 54
# Epoch [89/100], Loss: 0.0013
# Validation Accuracy: 0.8805
# TP: 380, FP: 50, TN: 423, FN: 59
# Epoch [90/100], Loss: 0.0014
# Validation Accuracy: 0.8783
# TP: 386, FP: 58, TN: 415, FN: 53
# Epoch [91/100], Loss: 0.0012
# Validation Accuracy: 0.8739
# TP: 386, FP: 62, TN: 411, FN: 53
# Epoch [92/100], Loss: 0.0011
# Validation Accuracy: 0.8783
# TP: 382, FP: 54, TN: 419, FN: 57
# Epoch [93/100], Loss: 0.0011
# Validation Accuracy: 0.8783
# TP: 384, FP: 56, TN: 417, FN: 55
# Epoch [94/100], Loss: 0.0011
# Validation Accuracy: 0.8761
# TP: 382, FP: 56, TN: 417, FN: 57
# Epoch [95/100], Loss: 0.0010
# Validation Accuracy: 0.8783
# TP: 378, FP: 50, TN: 423, FN: 61
# Epoch [96/100], Loss: 0.0009
# Validation Accuracy: 0.8772
# TP: 381, FP: 54, TN: 419, FN: 58
# Epoch [97/100], Loss: 0.0009
# Validation Accuracy: 0.8783
# TP: 382, FP: 54, TN: 419, FN: 57
# Epoch [98/100], Loss: 0.0009
# Validation Accuracy: 0.8761
# TP: 380, FP: 54, TN: 419, FN: 59
# Epoch [99/100], Loss: 0.0009
# Validation Accuracy: 0.8783
# TP: 374, FP: 46, TN: 427, FN: 65
# Epoch [100/100], Loss: 0.0008
# Validation Accuracy: 0.8750
# TP: 381, FP: 56, TN: 417, FN: 58

# %%
print(f"Maximum Validation Accuracy:  {max_val_accuracy:.3f}")
print("TP: ", max_TP)
print("FP: ", max_FP)
print("TN: ", max_TN)
print("FN: ", max_FN)

import math

MCC = (max_TP * max_TN - max_FP * max_FN) / math.sqrt((max_TP + max_FP) * (max_TP + max_FN) * (max_TN + max_FP) * (max_TN + max_FN))

print(f'Matthews Correlation Coefficient (MCC): {MCC:.3f}')

TPR = max_TP / (max_TP + max_FN)
FPR = max_FP / (max_FP + max_TN)

print(f'True Positive Rate (TPR): {TPR:.3f}')
print(f'False Positive Rate (FPR): {FPR:.3f}')
# Out:
# Maximum Validation Accuracy:  0.888
# TP:  381
# FP:  44
# TN:  429
# FN:  58
# Matthews Correlation Coefficient (MCC): 0.776
# True Positive Rate (TPR): 0.868
# False Positive Rate (FPR): 0.093

# %%
AI_embeddings = AI['embeddings']

with open('/home/csgrad/sunilruf/detect_llm/sunil_code/LLM/code.old/Deepfake_dataset/Squad/GPT/gpt_embeddings.npy', 'wb') as f:
    #for i in range(len(gpt['embeddings'])):
    np.save(f, AI_embeddings)
